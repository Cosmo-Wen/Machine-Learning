# %% [markdown]
# # 1. Introduction
#
# Welcome to your fourth assignment. In this assignment, you will build a convolutional neural network step by step. In this notebook, you will implement all the functions required to build a convolutional neural network.
#
# After finishing this assignment, you will have a deeper understanding of the process of training a convolutional neural network, which mainly consists of two parts: convolution layer and pooling layer.

# %% [markdown]
# # 2. Packages
# All the packages that you need to finish basic part of this assignment are listed below.
# *   numpy : The fundamental package for scientific computing with Python.
# *   matplotlib : A comprehensive library for creating static, animated, and interactive visualizations in Python.
# *   math : Python has a built-in module that you can use for mathematical tasks.
# *   pandas.read_csv : Provides functionality for reading a csv dataset from a GitHub repository.
# * sklearn.model_selection.train_test_split: A function helps you split train and test data.
# * os: A module provides the facility to establish the interaction between the user and the operating system. You can access the image directory by os.
# * cv2.imread: It is the module import name for opencv-python.
# * time: Provides various time-related functions.
# * google.colab.drive: Let you connect colab and your googol drive.
# * sys: Let you access system-specific parameters and functions.
#
# ⚠️ **WARNING** ⚠️:
# *   Please do not import any other packages in basic part.
# *   np.random.seed(seed) is used to keep all the random function calls consistent. It will help us grade your work. Please don't change the seed.
#
# ❗ **Important** ❗: Please do not change the code outside this code bracket.
# ```
# ### START CODE HERE ### (≈ n lines)
# ...
# ### END CODE HERE ###
# ```

# %%
# from google.colab import drive
# drive.mount('/content/drive')

# %%
import sys
# sys.path.append("/content/drive/....") ## the path of the directory where you place dense.py, activation.py ....
sys.path.append("./")

# %%
import os
import math
import time 
import numpy as np
from cv2 import imread, IMREAD_GRAYSCALE # IMREAD_GRAYSCALE allow you to load the image as gray scale image
from pandas import read_csv
import matplotlib.pyplot as plt

###### import your HW3 code (Don't change this part) ######
from Dense import Dense
from Activation import Activation
from Loss import compute_BCE_cost
from Predict import predict
##################################

output = {}
seed = 1
np.random.seed(seed)

# %% [markdown]
# # 3. Convolution layer
#
# In this section, you will need to implement a very important part of the convolutional neural network, which is the convolution layer. Convolution layer enables us to capture the important features of input images.
#
# You will have to implement two helper functions and the forward pass of the convolution layer. All you need to do is to follow the instructions and understand how each part works.

# %%
def zero_pad(X, pad):
    """
    Pad with zeros all images of the dataset X. The padding is applied to the height and width of an image.
    
    Argument:
    X -- python numpy array of shape (m, n_H, n_W, n_C), where m represent the number of examples.
    pad -- integer, amount of padding around each image on vertical and horizontal dimensions
    
    Returns:
    X_pad -- padded image of shape (m, n_H + 2*pad, n_W + 2*pad, n_C)
    """
    
    # GRADED FUNCTION: zero_padding
    ### START CODE HERE ### (≈ 1 line)
    X_pad = np.pad(X, ((0, 0), (pad, pad), (pad, pad), (0, 0)), "constant", constant_values = 0)
    ### END CODE HERE ###
    
    return X_pad

# %%
class Conv():
    def __init__(self, filter_size=2, input_channel=3, output_channel=8, pad=1, stride=1, seed=1):
        
        self.filter_size= filter_size
        self.input_channel=input_channel
        self.output_channel=output_channel
        self.seed = seed
        
        self.parameters = {"pad": pad, "stride": stride}
        self.initialize_parameters()
        
        
        self.name="conv"

    def initialize_parameters(self):
        """
        Argument:
        self.filter_size -- size of the filter
        self.input_channel -- size of the input channel
        self.output_channel -- size of the output channel
        self.parameters -- python dictionary containing your parameters:
                           W -- weight matrix of shape (filter_size, filter_size, input channel size, output channel size)
                           b -- bias vector of shape (1, 1, 1, output channel size)
                           pad -- amount of padding around each image on vertical and horizontal dimensions
                           stride -- represent the amount of movement that a filter move in one step
        """
        np.random.seed(seed)

        # GRADED FUNCTION: conv_initialization
        ### START CODE HERE ### (≈ 8 lines)
        limit = math.sqrt(6 / (self.input_channel + self.output_channel))
        W = np.random.uniform(-limit, limit, (self.filter_size,self.filter_size,self.input_channel,self.output_channel))
        b = np.zeros((1, 1, 1, self.output_channel), float)
        ### END CODE HERE ###

        assert(W.shape == (self.filter_size,self.filter_size,self.input_channel,self.output_channel))
        assert(b.shape == (1,1,1,self.output_channel))

        self.parameters['W'] = W
        self.parameters['b'] = b
        
    
    
    def conv_single_step(self, a_slice_prev, W, b):
        """
        Apply a filter W on a_slice_prev.

        Arguments:
        a_slice_prev -- slice of input data of shape (filter_size, filter_size, n_C_prev)
        W -- Weight parameters contained in a window - matrix of shape (filter_size, filter_size, n_C_prev)
        b -- Bias parameters contained in a window - matrix of shape (1, 1, 1)

        Returns:
        Z -- a scalar value, result of convolving the sliding window (W, b) on a slice x of the input data
        """

        # GRADED FUNCTION: conv_single_step
        ### START CODE HERE ### (≈ 3 lines)
        # Element-wise product between a_slice and W.
        s = a_slice_prev * W
        # Sum over all entries of the volume s.
        Z = np.sum(s)
        # Add bias b to Z. Cast b to a float() so that Z results in a scalar value.
        Z = Z + float(b)
        ### END CODE HERE ###

        return Z
    
    def forward(self, A_prev):
        """
        Implements the forward propagation for a convolution layer

        Arguments:
        A_prev -- output activations of the previous layer, numpy array of shape (m, n_H_prev, n_W_prev, n_C_prev)

        Returns:
        Z -- conv output, numpy array of shape (m, n_H, n_W, n_C)
        """

        # GRADED FUNCTION: conv_forward
        ### START CODE HERE ###
        # Retrieve dimensions from A_prev's shape (≈1 line)  
        (m, n_H_prev, n_W_prev, n_C_prev) = A_prev.shape

        # Retrieve dimensions from W's shape (≈1 line)
        (f, f, n_C_prev, n_C) = self.parameters['W'].shape


        # Compute the dimensions of the convolution output volume using the formula given below.(≈2 lines)
        n_H = int(np.floor((n_H_prev - f + 2 * self.parameters['pad']) / self.parameters['stride']) + 1)
        n_W = int(np.floor((n_W_prev - f + 2 * self.parameters['pad']) / self.parameters['stride']) + 1)

        # Initialize the output volume Z with zeros. (≈1 line)
        Z = np.zeros((m, n_H, n_W, n_C))

        # if pad!=0, create A_prev_pad by padding A_prev with the parameter "pad". (≈1 line)
        A_prev_pad = zero_pad(A_prev, self.parameters['pad'])

        for i in range(m):                               # loop over the batch of training examples
            a_prev_pad = A_prev_pad[i,:,:,:]               # Select ith training example's padded activation
            for h in range(n_H):                           # loop over vertical axis of the output volume
                for w in range(n_W):                       # loop over horizontal axis of the output volume
                    for c in range(n_C):                   # loop over channels (= #filter) of the output volume

                        # Find the corners of the current "slice" (≈4 lines)
                        vert_start = h * self.parameters['stride']
                        vert_end = h * self.parameters['stride'] + f
                        horiz_start = w * self.parameters['stride']
                        horiz_end = w * self.parameters['stride'] + f

                        # Use the corners to define the slice of a_prev_pad. (≈1 line)
                        a_slice_prev = a_prev_pad[vert_start: vert_end, horiz_start: horiz_end, : ]

                        # Convolve the (3D) slice with the correct filter W and bias b, to get back one output neuron. (≈1 line)
                        Z[i, h, w, c] = self.conv_single_step(a_slice_prev, self.parameters['W'][: , : , : , c], self.parameters['b'][: , : , : , c])

        ### END CODE HERE ###

        # Making sure your output shape is correct
        assert(Z.shape == (m, n_H, n_W, n_C))

        # Save information in "cache" for the backward pass
        self.cache = A_prev

        return Z
    
    def backward(self, dZ):
        """
        Implement the backward propagation for a convolution layer

        Arguments:
        dZ -- gradient of the cost with respect to the output of the conv layer (Z), numpy array of shape (m, n_H, n_W, n_C)

        Returns:
        dA_prev -- gradient of the cost with respect to the input of the conv layer (A_prev),
                   numpy array of shape (m, n_H_prev, n_W_prev, n_C_prev)
        """


        A_prev = self.cache

        # Retrieve dimensions from A_prev's shape
        (m, n_H_prev, n_W_prev, n_C_prev) = A_prev.shape

        # Retrieve dimensions from W's shape
        (f, f, n_C_prev, n_C) = self.parameters["W"].shape


        # Retrieve dimensions from dZ's shape
        (m, n_H, n_W, n_C) = dZ.shape

        # Initialize dA_prev, dW, db with the correct shapes
        dA_prev = np.zeros((m, n_H_prev, n_W_prev, n_C_prev))                           
        dW = np.zeros((f, f, n_C_prev, n_C))
        db = np.zeros((1, 1, 1, n_C))

        # Pad A_prev and dA_prev
        A_prev_pad = zero_pad(A_prev, self.parameters["pad"])
        dA_prev_pad = zero_pad(dA_prev, self.parameters["pad"])

        for i in range(m):                       # loop over the training examples

            # select ith training example from A_prev_pad and dA_prev_pad
            a_prev_pad = A_prev_pad[i]
            da_prev_pad = dA_prev_pad[i]

            for h in range(n_H):                   # loop over vertical axis of the output volume
                for w in range(n_W):               # loop over horizontal axis of the output volume
                    for c in range(n_C):           # loop over the channels of the output volume

                        # Find the corners of the current "slice"
                        vert_start = h * self.parameters["stride"]
                        vert_end = vert_start + f
                        horiz_start = w * self.parameters["stride"]
                        horiz_end = horiz_start + f

                        # Use the corners to define the slice from a_prev_pad
                        a_slice = a_prev_pad[vert_start:vert_end, horiz_start:horiz_end, :]

                        # Update gradients for the window and the filter's parameters
                        da_prev_pad[vert_start:vert_end, horiz_start:horiz_end, :] += self.parameters["W"][:,:,:,c] * dZ[i, h, w, c]
                        dW[:,:,:,c] += a_slice * dZ[i, h, w, c]
                        db[:,:,:,c] += dZ[i, h, w, c]

            # Set the ith training example's dA_prev to the unpaded da_prev_pad
            dA_prev[i, :, :, :] = da_prev_pad[self.parameters["pad"]:da_prev_pad.shape[0]-self.parameters["pad"], 
                                              self.parameters["pad"]:da_prev_pad.shape[1]-self.parameters["pad"], :]

        assert(dA_prev.shape == (m, n_H_prev, n_W_prev, n_C_prev))

        self.dW = dW
        self.db = db

        return dA_prev
    
    def update(self, learning_rate):
        """
        Update parameters using gradient descent
        
        Arguments:
        learning rate -- step size
        """

        # GRADED FUNCTION: conv_update
        ### START CODE HERE ### (≈ 2 lines of code)
        self.parameters["W"] = self.parameters["W"] - learning_rate * self.dW
        self.parameters["b"] = self.parameters["b"] - learning_rate * self.db
        ### END CODE HERE ###

# %% [markdown]
# ## 3.1 initialization
# Using Glorot uniform initialization to initialize the convolution layer's filters with the parameters: filter_size, input_channel, and output_channel.
#
# *   Use random initialization (uniform distribution) for the weight matrices. Draws samples from a uniform distribution within [-limit, limit], where limit = sqrt(6 / (fan_in + fan_out)), fan_in is the **number of input channel** and fan_out is the **number of output channel**. However, in the usual implementation, we will consider fan_in and fan_out as the number of input units and the number of output units.
# *   Use zero initialization for the biases.
#
# Exercise: Create and initialize parameters of a convolution layer using Glorot uniform initialization. (1%)
#
# It will take following parameters to initialize the convolution layer:
# *   filter_size: The filter will be in the shape of (filter_size*filter_size)
# *   input_channel: size of the input channel
# *   output_channel: size of the output channel
# *   pad: amount of padding around each image on vertical and horizontal dimensions
# *   stride: represent the amount of movement that a filter move in one step

# %%
np.random.seed(seed)
conv = Conv(filter_size=2, input_channel=3, output_channel=8, pad=2, stride=2)
print("W[0][0][0] = ",  conv.parameters["W"][0][0][0])
print("b = ", conv.parameters["b"])

np.random.seed(seed)
conv = Conv(filter_size=2, input_channel=3, output_channel=16, pad=2, stride=2)
output["conv_initialization"] = conv.parameters["W"][0][0][0]
# Out:
# W[0][0][0] =  [-0.12256662  0.32544084 -0.73838    -0.29197414 -0.52177613 -0.6021558
#  -0.46342438 -0.22812192]
# b =  [[[[0. 0. 0. 0. 0. 0. 0. 0.]]]]

# %% [markdown]
# Expected output:
# <table>
#   <tr>
#     <td>W[0][0][0]: </td>
#     <td>[-0.12256662  0.32544084 -0.73838    -0.29197414 -0.52177613 -0.6021558 -0.46342438 -0.22812192]</td>
#   </tr>
#   <tr>
#     <td>b: </td>
#     <td>[[[[0. 0. 0. 0. 0. 0. 0. 0.]]]]</td>
#   </tr>
# </table>

# %% [markdown]
# ## 3.2  Zero-Padding
#
# Pad around each image on vertical and horizontal dimensions with zero.
#
# 1. It allows you to use a convolution layer without necessarily shrinking the height and width of the volumes. This is important for building deeper networks since otherwise the height/width would shrink as you go to deeper layers.
# 2. It helps us keep more of the information at the border of an image. Without padding, very few values at the next layer would be affected by pixels as the edges of an image.
#
# **Exercise**: Implement the zero_pad() function to pad the input X with the given parameter "pad". (3%)
#
# This function takes the following inputs:
# *   X: input.
# *   pad: amount of padding around each image on vertical and horizontal dimensions.

# %%
np.random.seed(seed)
x = np.random.randn(4, 3, 3, 2)
x_pad = zero_pad(x, 2)
print ("x.shape =\n", x.shape)
print ("x_pad.shape =\n", x_pad.shape)
print ("x[0,2,:,0] =\n", x[0,2,:,0])
print ("x_pad[0,2,:,0] =\n", x_pad[0,2,:,0])

fig, axarr = plt.subplots(1, 2)
axarr[0].set_title('x')
axarr[0].imshow(x[0,:,:,0])
axarr[1].set_title('x_pad')
axarr[1].imshow(x_pad[0,:,:,0])

np.random.seed(seed)
x = np.random.randn(4, 2, 2, 2)
x_pad = zero_pad(x, 1)
output["zero_padding"] = x_pad[0,1,:,0]
# Out:
# x.shape =
#  (4, 3, 3, 2)
# x_pad.shape =
#  (4, 7, 7, 2)
# x[0,2,:,0] =
#  [-0.3224172   1.13376944 -0.17242821]
# x_pad[0,2,:,0] =
#  [ 0.          0.          1.62434536 -0.52817175  0.86540763  0.
#   0.        ]

# %% [markdown]
# Expected output:
# <table>
#   <tr>
#     <td>x.shape: </td>
#     <td>(4, 3, 3, 2)</td>
#   </tr>
#   <tr>
#     <td>x_pad.shape: </td>
#     <td>(4, 7, 7, 2)</td>
#   </tr>
#   <tr>
#     <td>x[0,2,:,0]: </td>
#     <td>[-0.3224172   1.13376944 -0.17242821]</td>
#   </tr>
#   <tr>
#     <td>x_pad[0,2,:,0]: </td>
#     <td>[ 0. 0. 1.62434536 -0.52817175 0.86540763 0. 0.]
# </td>
#   </tr>
# </table>

# %% [markdown]
# ## 3.3 Convolution_single_step
# In this part, you will implement a single step of convolution, in which you apply the filter to a single position of the input. This will be used to build a convolutional unit.
#
# We will convolve an f*f filter with the image by multiplying its values element-wise with the original matrix, then summing them up and adding a bias.
#
# **Exercise**: Implement conv_single_step( ). (5%)
#
# This function takes the following inputs:
# *   a_slice_prev: the output of the activation by the previous layer.
# *   W: the filter with size f*f.
# *   b: the bias.

# %%
np.random.seed(seed)
a_slice_prev = np.random.randn(4, 4, 3)
W = np.random.randn(4, 4, 3)
b = np.random.randn(1, 1, 1)

conv = Conv(filter_size=2, input_channel=3, output_channel=8, pad=2, stride=2)
Z = conv.conv_single_step(a_slice_prev, W, b)
print("Z =", Z)

np.random.seed(seed)
a_slice_prev = np.random.randn(3, 3, 3)
W = np.random.randn(3, 3, 3)
b = np.random.randn(1, 1, 1)
conv = Conv()
Z = conv.conv_single_step(a_slice_prev, W, b)
output["conv_single_step"] = Z
# Out:
# Z = -6.999089450680221

# %% [markdown]
# Expected output:
# <table>
#   <tr>
#     <td>Z: </td>
#     <td>-6.999089450680221</td>
#   </tr>
# </table>

# %% [markdown]
# ## 3.4 Forward pass
# In the forward pass, you will take many filters and convolve them through the input. Each 'convolution' gives you a 2D matrix output. You will then stack these outputs to get a 3D volume.
#
# Notice that the output shape of the convolution forward will be (H, W, C).
# * $H= \lfloor\frac{H_{prev }-f+2*pad}{stride}\rfloor+1$
# * $W= \lfloor\frac{W_{prev }-f+2*pad}{stride}\rfloor+1$
# * $C = $ number of filters
#
# f = filter_size
#
# **Exercise**: Implement forward( ) to convolve the filters W on an input activation A_prev. (15%)
#
# This function takes the following input:
# *   A_prev: the output of the activation by the previous layer, it's an array with shape (m, H_prev, W_prev, C_prev).
#     *  m: number of examples.
#     *  H_prev, W_prev, C_prev: the height, width, and channel of the output of the previous layer.
#
# Here are some steps for you to finish this exercise:
# 1. Define **a_slice_prev**, which represent the input slice of conv_single_step( ).
# 2. To define **a_slice_prev**, you have to define its' corners: **vert_start, vert_end, horiz_start and horiz_end**.

# %%
np.random.seed(seed)
A_prev = np.random.randn(10,4,4,3)
conv=Conv(filter_size=2, input_channel=3, output_channel=8, pad=2, stride=2)
Z = conv.forward(A_prev)

print("Z's mean =", np.mean(Z))
print("Z[3,2,1] =", Z[3,2,1])
print("cache_conv[1][2][3] =", conv.cache[1][2][3])


np.random.seed(seed)
A_prev = np.random.randn(10,3,3,3)
conv=Conv(filter_size=3, input_channel=3, output_channel=16, pad=1, stride=1)
Z = conv.forward(A_prev)

output["conv_forward_1"] = np.mean(Z)
output["conv_forward_2"] = Z[3,2,1]
output["conv_forward_3"] = conv.cache[1][2][2]
# Out:
# Z's mean = 0.0031904169881830785
# Z[3,2,1] = [ 1.32947002  2.12083471  0.37853495 -3.53602735  1.38816885 -1.01503137
#  -1.01667531  0.86993377]
# cache_conv[1][2][3] = [-0.20075807  0.18656139  0.41005165]

# %% [markdown]
# Expected output:
# <table>
#   <tr>
#     <td>Z's mean: </td>
#     <td>0.0031904169881830785</td>
#   </tr>
#   <tr>
#     <td>Z[3,2,1]: </td>
#     <td>[ 1.32947002  2.12083471  0.37853495 -3.53602735  1.38816885 -1.01503137
#  -1.01667531  0.86993377]</td>
#   </tr>
#   <tr>
#     <td>cache_conv[1][2][3]: </td>
#     <td>[-0.20075807  0.18656139  0.41005165]</td>
#   </tr>
# </table>

# %% [markdown]
# ## 3.5 Update parameters
# In this section you will update the parameters of the convolution layer, using gradient descent:
#
# $$ W^{[l]} = W^{[l]} - \alpha \text{ } dW^{[l]} $$$$ b^{[l]} = b^{[l]} - \alpha \text{ } db^{[l]} $$
#
# **Exercise**: Implement update( ) to update your parameters using gradient descent. (1%)
#
# **Instructions**:
# *   Update parameters using gradient descent on $W^{[l]}$ and $b^{[l]}$.

# %%
conv=Conv(filter_size=2, input_channel=3, output_channel=8, pad=2, stride=2)
np.random.seed(seed)
conv.dW = np.random.randn(2, 2, 3, 8)
conv.db = np.random.randn(1, 1, 1, 8)
conv.update(1.0)
print("W[0][0][0] = ", conv.parameters["W"][0][0][0])
print("b = ", conv.parameters["b"])

conv=Conv(filter_size=3, input_channel=3, output_channel=8, pad=1, stride=2)
np.random.seed(seed)
conv.dW = np.random.randn(3, 3, 3, 8)
conv.db = np.random.randn(1, 1, 1, 8)
conv.update(0.1)
output["conv_update_1"] = conv.parameters["W"][0][0][0]
output["conv_update_2"] = conv.parameters["b"]
# Out:
# W[0][0][0] =  [-1.74691199  0.93719726 -0.21020825  0.78099448 -1.38718376  1.69938289
#  -2.20823614  0.53308498]
# b =  [[[[ 0.34385368 -0.04359686  0.62000084 -0.69803203  0.44712856
#     -1.2245077  -0.40349164 -0.59357852]]]]

# %% [markdown]
# Expected output:
# <table>
#   <tr>
#     <td>W[0][0][0]: </td>
#     <td>[-1.74691199  0.93719726 -0.21020825  0.78099448 -1.38718376  1.69938289 -2.20823614  0.53308498]</td>
#   </tr>
#   <tr>
#     <td>b: </td>
#     <td>[[[[ 0.34385368 -0.04359686  0.62000084 -0.69803203  0.44712856
#     -1.2245077  -0.40349164 -0.59357852]]]]</td>
#   </tr>
# </table>

# %% [markdown]
# # 4. Maxpooling layer
#
# The pooling layer reduces the size (height and width) of the input. It helps reduce computation, as well as helps make feature detectors more invariant to their position in the input. In this section, we will focus on maxpooling layer.

# %%
class MaxPool():
    def __init__(self, filter_size=2, stride=2):
        """
        Argument:
        self.parameters -- python dictionary containing your parameters:
                           f -- size of a filter
                           stride -- the amount of movement that a filter move in one step
        """
    
        self.parameters = {"f": filter_size, "stride": stride}
        self.name="maxpool"
        
        
    def forward(self, A_prev):
        """
        Implements the forward pass of the max pooling layer

        Arguments:
        A_prev -- Input data, numpy array of shape (m, n_H_prev, n_W_prev, n_C_prev)

        Returns:
        A -- output of the pool layer, a numpy array of shape (m, n_H, n_W, n_C)
        """

        # GRADED FUNCTION: maxpool_forward
        ### START CODE HERE ###
        # Retrieve dimensions from the input shape. (≈1 line)
        (m, n_H_prev, n_W_prev, n_C_prev) = A_prev.shape


        # Define the dimensions of the output. (≈3 lines)
        n_H = int(np.floor((n_H_prev - self.parameters['f']) / self.parameters['stride']) + 1)
        n_W = int(np.floor((n_W_prev - self.parameters['f']) / self.parameters['stride']) + 1)
        n_C = n_C_prev

        # Initialize output matrix A with zeros. (≈1 line)
        A = np.zeros((m, n_H, n_W, n_C))            

        for i in range(m):                         # loop over the training examples
            for h in range(n_H):                     # loop on the vertical axis of the output volume
                for w in range(n_W):                 # loop on the horizontal axis of the output volume
                    for c in range (n_C):            # loop over the channels of the output volume

                        # Find the corners of the current "slice". (≈4 lines)
                        vert_start = h * self.parameters["stride"]
                        vert_end = vert_start + self.parameters['f']
                        horiz_start = w * self.parameters["stride"]
                        horiz_end = horiz_start + self.parameters['f']

                        # Use the corners to define the current slice on the ith training example of A_prev, channel c. (≈1 line)
                        a_prev_slice = A_prev[i, vert_start: vert_end, horiz_start: horiz_end, : ]

                        # Compute the max pooling operation on a_prev_slice. (≈1 line)
                        A[i, h, w, c] = np.max(a_prev_slice[: , : , c])

        ### END CODE HERE ###

        # Store the input in "cache" for backward pass
        self.cache = A_prev

        # Making sure your output shape is correct
        assert(A.shape == (m, n_H, n_W, n_C))

        return A
    
    def create_mask_from_window(self, x):
        """
        Creates a mask from an input x to identify the max entry of x.

        Arguments:
        x -- Array of shape (filter_size, filter_size)

        Returns:
        mask -- Array of the same shape as filter, contains a True at the position corresponding to the max entry of x.
        """

        mask = x == np.max(x)

        return mask
    
    def backward(self, dA):
        """
        Implements the backward pass of the max pooling layer

        Arguments:
        dA -- gradient of cost with respect to the output of the pooling layer, same shape as A 

        Returns:
        dA_prev -- gradient of cost with respect to the input of the pooling layer, same shape as A_prev
        """

        # Retrieve information from cache
        A_prev = self.cache

        # Retrieve dimensions from A_prev's shape and dA's shape
        m, n_H_prev, n_W_prev, n_C_prev = A_prev.shape
        m, n_H, n_W, n_C = dA.shape

        # Initialize dA_prev with zeros
        dA_prev = np.zeros(A_prev.shape)

        for i in range(m):  # loop over the training examples
            # select training example from A_prev                    
            a_prev = A_prev[i]
            for h in range(n_H):   # loop on the vertical axis            
                for w in range(n_W):  # loop on the horizontal axis             
                    for c in range(n_C): # loop over the channels

                        # Find the corners of the current "slice"          
                        vert_start = h * self.parameters["stride"]
                        vert_end = vert_start + self.parameters["f"]
                        horiz_start = w * self.parameters["stride"]
                        horiz_end = horiz_start + self.parameters["f"] 

                        #Use the corners and "c" to define the current slice from a_prev
                        a_prev_slice = a_prev[vert_start:vert_end, horiz_start:horiz_end, c]
                        # Create the mask from a_prev_slice
                        mask = self.create_mask_from_window(a_prev_slice)
                        # Set dA_prev to be dA_prev + (the mask multiplied by the correct entry of dA)
                        dA_prev[i, vert_start:vert_end, horiz_start:horiz_end, c] += np.multiply(mask, dA[i, h, w, c])



        # Make sure your output shape is correct
        assert(dA_prev.shape == A_prev.shape)

        return dA_prev

# %% [markdown]
# ## 4.1 Forward pass
#
# It will take following parameters to initialize a max pooling layer:
# *   filter_size: the filter will be in the shape of (filter_size*filter_size)
# *   stride: the amount of movement that a filter move in one step
#
# In the forward pass, you will slide a ( f*f ) filter over the input and store the max value of the window in the output. (f means the filter size)
#
# Notice that the output shape of the forward pass will be (H, W, C).
# * $H= \lfloor\frac{H_{prev }-f}{stride}\rfloor+1$
# * $W= \lfloor\frac{W_{prev }-f}{stride}\rfloor+1$
# * $C = C_{prev}$
#
# **Exercise**: Create a max pooling layer and implement the forward pass of the pooling layer. (15%)
#
# This forward function takes the following input:
# *   A_prev: the output of the previous layer, it's an array with shape (m, H_prev, W_prev, C_prev).

# %%
np.random.seed(seed)
A_prev = np.random.randn(2, 4, 4, 3)
maxpool=MaxPool(filter_size=3, stride=2)
A = maxpool.forward(A_prev)
print("A =", A)

A_prev = np.random.randn(2, 5, 5, 3)
maxpool=MaxPool(filter_size=2, stride=1)
A = maxpool.forward(A_prev)
output["maxpool_forward"] = A
# Out:
# A = [[[[1.74481176 0.86540763 1.13376944]]]
#
#
#  [[[1.13162939 1.51981682 2.18557541]]]]

# %% [markdown]
# Expected output:
# <table>
#   <tr>
#     <td>A: </td>
#     <td>[[[[1.74481176 0.86540763 1.13376944]]] [[[1.13162939 1.51981682 2.18557541]]]]</td>
#   </tr>
# </table>

# %% [markdown]
# # 5. Flatten layer

# %% [markdown]
# To connect the convolution layer and the dense layer, you should flatten the output of the convolution layer or max pooling layer before dense layer.

# %%
class Flatten():
    def __init__(self):
        self.name="flatten"

    def forward(self, A_prev):
        """
        Implements the forward pass of the flatten layer

        Arguments:
        A_prev -- Input data, numpy array of shape (m, n_H_prev, n_W_prev, n_C_prev)

        Returns:
        A -- output of the flatten layer, a 1-dimensional array
        """

        # Save information in "cache" for the backward pass
        self.cache = A_prev[0].shape

        # GRADED FUNCTION: flatten_forward
        ### START CODE HERE ### (≈1 line)
        A = np.array([i.flatten() for i in A_prev])
        ### END CODE HERE ###
        return A

    def backward(self, dA):
        """
        Implements the backward pass of the flatten layer

        Arguments:
        dA -- Input data, a 1-dimensional array

        Returns:
        dA_prev -- An array with its original shape (the output shape of its' previous layer).
        """
        # GRADED FUNCTION: flatten_backward
        ### START CODE HERE ### (≈1 line)
        dA_prev = np.array([i.reshape(self.cache) for i in dA])
        ### END CODE HERE ###
        return dA_prev

# %% [markdown]
# ## 5.1 Forward pass
#
# **Exercise**: Implement the forward pass of flatten layer. Turn the input array into a 1-dimensional array. (5%)
#
# This function takes the following input:
# *   A_prev: Input data, it's an array with shape (m, n_H_prev, n_W_prev, n_C_prev).

# %%
np.random.seed(seed)
A_prev = np.random.randn(2,2,2,2)
flatten = Flatten()
A = flatten.forward(A_prev)
print("A.shape =", A.shape)
print("A[0] =", A[0])


np.random.seed(seed)
A_prev = np.random.randn(2,3,3,2)
flatten = Flatten()
A = flatten.forward(A_prev)
output["flatten_forward"] = A[0]
# Out:
# A.shape = (2, 8)
# A[0] = [ 1.62434536 -0.61175641 -0.52817175 -1.07296862  0.86540763 -2.3015387
#   1.74481176 -0.7612069 ]

# %% [markdown]
# Expected output:
# <table>
#   <tr>
#     <td>A.shape: </td>
#     <td>(2, 8)</td>
#   </tr>
#   <tr>
#     <td>A[0]: </td>
#     <td>[ 1.62434536 -0.61175641 -0.52817175 -1.07296862  0.86540763 -2.3015387
#   1.74481176 -0.7612069 ]</td>
#   </tr>
# </table>

# %% [markdown]
# ## 5.2  Backward pass
#
# **Exercise**: Implement the backward pass of flatten layer. Turn the input array back to its original shape.(the output shape of its' previous layer). (5%)
#
# This function takes the following input:
# *   dA: the output of backward pass from the next layer, it's a 1-dimensional array.

# %%
np.random.seed(seed)
A_prev = np.random.randn(2,2,2,2)
flatten = Flatten()
A = flatten.forward(A_prev)
B = flatten.backward(A)
print("B.shape =", B.shape)
print("B[0] =", B[0])

# B and A_prev should be same
assert((B==A_prev).all())

np.random.seed(seed)
A_prev = np.random.randn(4,3,3,3)
flatten = Flatten()
A = flatten.forward(A_prev)
B = flatten.backward(A)
output["flatten_backward"] = B[0]
# Out:
# B.shape = (2, 2, 2, 2)
# B[0] = [[[ 1.62434536 -0.61175641]
#   [-0.52817175 -1.07296862]]
#
#  [[ 0.86540763 -2.3015387 ]
#   [ 1.74481176 -0.7612069 ]]]

# %% [markdown]
# Expected output:
# <table>
#   <tr>
#     <td>B.shape: </td>
#     <td>(2, 2, 2, 2)</td>
#   </tr>
#   <tr>
#     <td>B[0]: </td>
#     <td>[[[ 1.62434536 -0.61175641]
#   [-0.52817175 -1.07296862]]
#   [[ 0.86540763 -2.3015387 ]
#   [ 1.74481176 -0.7612069 ]]]</td>
#   </tr>
# </table>

# %% [markdown]
# # 6. Model
# Alright, now you have all the tools that are needed to build a convolutional neural network. Let's get started! Use the knowledge you learned from assignment 4 to finish this part. But there is some difference:
#
# 1. In this part, we will call model.add( ) to add a layer into the model. For example:
# * model.add(Conv( )): add a convolution layer into the model.
# * model.add(Dense( )): add a dense layer into the model.
# * model.add(Activation( )): add an activation layer into the model.
#
# 2. Because the dense layer you implement in assignment3 takes the input shape as [:, m], where m represents the number of examples. However, when the training data go through the convolution layer and maxpool layer, its shape will be [m,:]. As a consequence, in the forward pass, the output of flatten.forward( ) need to be transposed. Similarly, in the backward pass, before the data goes into flatten.backward( ), it needs to be transposed again.

# %%
class Model():
    def __init__(self):       
        self.layers=[]

    def add(self, layer):
        self.layers.append(layer)

    def forward(self, X):
        A = X
        # GRADED FUNCTION: model
        ### START CODE HERE ### (≈ 5 lines)
        for l in range(len(self.layers)):
            if(self.layers[l].name=="flatten"):
                A=self.layers[l].forward(A).T # Transpose after flatten layer
            else:
                A = self.layers[l].forward(A)
        ### END CODE HERE ###
        return A

    def backward(self, AL=None, Y=None):
        L = len(self.layers)

        # GRADED FUNCTION: model
        ### START CODE HERE ### (≈ 7 lines)
        if self.layers[-1].name == "sigmoid":
            dAL = - (np.divide(Y, AL + 1e-5) - np.divide(1 - Y, 1 - AL + 1e-5)) 
            dZ = self.layers[-1].backward(dA=dAL)  #activation layer backward
            dA_prev = self.layers[-2].backward(dZ) #linear layer backward
        else:
            dZ = self.layers[-1].backward(Y=Y)
            dA_prev = self.layers[-2].backward(dZ)
        ### END CODE HERE ###

        
        # Loop from l=L-3 to l=0
        # GRADED FUNCTION: model
        ### START CODE HERE ### (≈ 5 lines)
        for l in reversed(range(L-2)):
            if(self.layers[l].name=="flatten"):
                dA_prev=self.layers[l].backward(dA_prev.T) # Transpose before goes into flatten layer
            else:
                dA_prev = self.layers[l].backward(dA_prev)
        ### END CODE HERE ###

        return dA_prev

    def update(self, learning_rate):
        """
        Arguments:
        learning_rate -- step size
        """
        
        # GRADED FUNCTION: model
        # Only convolution layer and dense layer have to update parameters
        ### START CODE HERE ### (≈ 3 lines)
        for l in range(len(self.layers)):
            if self.layers[l].name == "conv" or self.layers == "dense":
                self.layers[l].update(learning_rate)
        ### END CODE HERE ###

# %% [markdown]
# ## 6.1 Model forward, backward and update:
# **Exercise**: Here is an exercise to make sure your model works correctly. (5%)

# %%
np.random.seed(seed)
A = np.random.randn(4,10,10,3)
Y = np.array([[1,0,1,0]])

model=Model()
model.add(Conv(filter_size=3, input_channel=3, output_channel=8, pad=1, stride=2))
model.add(Activation("relu"))
model.add(MaxPool(filter_size=2, stride=2))
model.add(Flatten())
model.add(Dense(32, 1))
model.add(Activation("sigmoid"))


AL = model.forward(A)
dA_prev = model.backward(AL=AL, Y=Y)
model.update(0.01)

print(model.layers[0].dW[0,0,0])
print(model.layers[0].db)
print(model.layers[4].dW[0,:8])
print(model.layers[4].db)


np.random.seed(seed)
A = np.random.randn(4,8,8,3)
Y = np.array([[1,1,0,0]])

model=Model()
model.add(Conv(filter_size=3, input_channel=3, output_channel=16, pad=1, stride=2))
model.add(Activation("relu"))
model.add(MaxPool(filter_size=2, stride=2))
model.add(Flatten())
model.add(Dense(64, 1))
model.add(Activation("sigmoid"))


AL = model.forward(A)
dA_prev = model.backward(AL=AL, Y=Y)
model.update(0.001)

output["model_1"] = model.layers[0].dW[0,0,0]
output["model_2"] = model.layers[0].db
output["model_3"] = model.layers[4].dW[0,:8]
output["model_4"] = model.layers[4].db
# Out:
# [ 0.36135339 -0.08462337 -0.00125603 -0.75846791 -0.10766644 -0.30566005
#  -0.6160899   0.17289454]
# [[[[-0.17413437 -1.16136976  2.2091218   1.09197293  1.09878206
#     -0.99630691  2.22696487 -0.20973624]]]]
# [-2.14606176 -0.75085187 -1.19750975 -0.8916535  -0.91436404 -0.76753
#  -1.30207298 -0.52670234]
# [[-0.47493517]]

# %% [markdown]
# Expected output:
# <table>
#   <tr>
#     <td>model.layers[0].dW[0,0,0]: </td>
#     <td>[ 0.36135339 -0.08462337 -0.00125603 -0.75846791 -0.10766644 -0.30566005
#  -0.6160899   0.17289454]</td>
#   </tr>
#   <tr>
#     <td>model.layers[0].db: </td>
#     <td>[[[[-0.17413437 -1.16136976  2.2091218   1.09197293  1.09878206
#     -0.99630691  2.22696487 -0.20973624]]]]</td>
#   </tr>
#   <tr>
#     <td>model.layers[4].dW[0,:8]: </td>
#     <td>[-2.14606176 -0.75085187 -1.19750975 -0.8916535  -0.91436404 -0.76753
#  -1.30207298 -0.52670234]</td>
#   </tr>
#   <tr>
#     <td>model.layers[4].db: </td>
#     <td>[[-0.47493517]]</td>
#   </tr>
# </table>

# %% [markdown]
# # 7. Binary classification
#
# Congratulations on implementing all the functions by yourself. You have done an incredible job! 👏
#
# Now you have all the tools you need to get started with classification. In this section, you will build a binary classifier using the functions you had previously written. You will create a model that can determine whether a CXR image is normal or not. There will be 600 training images and 60 testing images, and the size of all images are 32 * 32 * 1.
#
#
# **Exercise**: Implement a binary classifier and tune the hyperparameter. You will get all 10% if your prediction achieves accuracy greater than 0.55 in testing data. (10%)
#
# **Instruction**:
# *   You can only use the functions you had previously written.
# *   Preprocess the data by using min-max scaling to normalize X. Normalize the values of each feature between 0 and 1.
# *   Use batch gradient descent to train the model.

# %% [markdown]
# ## 7.1 Data preprocessing

# %%
PATH = "Training_data"  #path to your training image
file_dir = os.listdir(PATH) #read the images from the directory
file_dir.sort() #Make sure the images are loaded in order
X_train = np.array([])

# Prepare X_train
# The shape of X_train will be (number of examples, height of image, width of image, channel of image)
# GRADED CODE: Binary classification (Data preprocessing)
# hint: use imread(PATH, IMREAD_GRAYSCALE) to load image
### START CODE HERE ### (≈ 9 line)
X_train = np.array([imread(PATH + "/" + i, IMREAD_GRAYSCALE) for i in file_dir])[: , : , : , np.newaxis] / 255

### END CODE HERE ###### END CODE HERE ###

# %%
PATH = "Testing_data"  #path to your testing image
file_dir = os.listdir(PATH)
file_dir.sort()
X_test = np.array([])

# Prepare X_testi
# The shape of X_teset will be (number of examples, height of image, width of image, channel of image)
# GRADED CODE: Binary classification (Data preprocessing)
### START CODE HERE ### (≈ 9 line)
X_test = np.array([imread(PATH + "/" + i, IMREAD_GRAYSCALE) for i in file_dir])[: , : , : , np.newaxis] / 255
### END CODE HERE ###### END CODE HERE ###

# %%
data = read_csv("Training_label.csv")

y_train = []
# Prepare y_train
# The shape of y_train will be (number of examples, 1), we will transpose y_train latter.
# GRADED CODE: Binary classification (Data preprocessing)
### START CODE HERE ### (≈ 2 line)
y_train = np.array(data['label'])[: , np.newaxis]

### END CODE HERE ###

# %%
from sklearn.model_selection import train_test_split
#You can split training and validation set here. (Optional)
### START CODE HERE ###
validation = True
if validation and y_train.shape[0] == data.shape[0]:
    X_train, X_val, y_train, y_val = train_test_split(X_train, y_train, test_size=0.1)
### END CODE HERE ###

# %%
y_train = y_train.T #transpose y_train
y_val = y_val.T

# plot first few images
for i in range(9):
    # define subplot
    plt.subplot(330 + 1 + i)
    # plot raw pixel data
    plt.imshow(X_train[i].squeeze(), cmap='gray', vmin=0, vmax=1)
# show the figure
plt.show()

# check the shape of training data and testing data
print('Train: X=%s, y=%s' % (X_train.shape, y_train.shape))
print('Val: X=%s, y=%s' % (X_val.shape, y_val.shape))
print('Test: X=%s' % (X_test.shape, ))
# Out:
# Train: X=(540, 32, 32, 1), y=(1, 540)
# Val: X=(60, 32, 32, 1), y=(1, 60)
# Test: X=(60, 32, 32, 1)

# %% [markdown]
# ## 7.2 mini-batch gradient descent

# %%
def random_mini_batches(X, Y, mini_batch_size = 64):
    """
    Creates a list of random minibatches from (X, Y)
    
    Arguments:
    X -- input data, of shape !!!!!!!!!!!(number of examples ,input size)!!!!!!!!!!!
    Y -- true "label" vector, of shape (number of classes, number of examples)
    mini_batch_size -- size of the mini-batches, integer
    
    Returns:
    mini_batches -- list of synchronous (mini_batch_X, mini_batch_Y)
    """
    
    m = X.shape[0]  # number of training examples
    mini_batches = []

    # GRADED CODE: Binary classification
    ### START CODE HERE ###
        
    # Step 1: Shuffle (X, Y)
    permutation = list(np.random.permutation(m))
    shuffled_X = np.array([X[p] for p in permutation])
    shuffled_Y = np.array([Y[: , p] for p in permutation])
    
    inc = mini_batch_size

    # Step 2 - Partition (shuffled_X, shuffled_Y).
    # Cases with a complete mini batch size only i.e each of 64 examples.
    num_complete_minibatches = math.floor(m / mini_batch_size) # number of mini batches of size mini_batch_size in your partitionning
    for k in range(0, num_complete_minibatches):
        # (approx. 2 lines)
        mini_batch_X = shuffled_X[k * mini_batch_size: (k + 1) * mini_batch_size]
        mini_batch_Y = shuffled_Y[k * mini_batch_size: (k + 1) * mini_batch_size]
        mini_batch = (mini_batch_X, mini_batch_Y)
        mini_batches.append(mini_batch)
    
    # For handling the end case (last mini-batch < mini_batch_size i.e less than 64)
    if m % mini_batch_size != 0:
        #(approx. 2 lines)
        mini_batch_X = shuffled_X[num_complete_minibatches * mini_batch_size: ]
        mini_batch_Y = shuffled_Y[num_complete_minibatches * mini_batch_size: ]
        mini_batch = (mini_batch_X, mini_batch_Y)
        mini_batches.append(mini_batch)
    
    
    return mini_batches

    ### END CODE HERE ###

# %% [markdown]
# ## 7.3 Start training

# %%
# GRADED CODE: Binary classification
### START CODE HERE ###
learning_rate = 0.001
num_iterations = 20
batch_size = 16
print_cost = True
classes = 2
costs = []   # keep track of cost
accs = []

# build the model
model=Model()
model.add(Conv(filter_size=3, input_channel=1, output_channel=16, pad=0, stride=2))
model.add(Activation("relu"))
model.add(MaxPool(filter_size=2, stride=2))
model.add(Conv(filter_size=3, input_channel=16, output_channel=16, pad=0, stride=2))
model.add(Activation("relu"))

model.add(Flatten())
model.add(Dense(144, 32))
model.add(Activation("relu"))
model.add(Dense(32, 1))
model.add(Activation("sigmoid"))

# Loop (gradient descent)
for i in range(0, num_iterations):
    if i == 15:
        learning_rate = 3e-5
    print("epoch: ",i)
    mini_batches = random_mini_batches(X_train, y_train, batch_size)
    for batch in mini_batches:
        x_batch, y_batch = batch

        # forward
        AL = model.forward(x_batch)

        # compute cost
        if classes == 2:
            cost = compute_BCE_cost(AL, np.transpose(y_batch))
        else:
            cost = compute_CCE_cost(AL, np.transpose(y_batch))

        # backward
        dA_prev = model.backward(AL = AL, Y = y_batch)

        # update
        model.update(learning_rate)
    acc = np.sum(predict(X_val, None, model, 2) == y_val) / y_val.shape[1]
    print ("Cost after iteration %i: %f" %(i, cost))
    costs.append(cost)
    print("Accuracy after iteration %i: %f" %(i, acc))
    accs.append(acc)
### END CODE HERE ###
            
# plot the cost
plt.plot(np.squeeze(costs))
plt.ylabel('cost')
plt.xlabel('iterations')
plt.title("Learning rate =" + str(learning_rate))
plt.show()

plt.plot(np.squeeze(accs))
plt.ylabel('accuracy')
plt.xlabel('iterations')
plt.title("Learning rate =" + str(learning_rate))
plt.show()
# Out:
# epoch:  0
# Cost after iteration 0: 0.806894
# Accuracy after iteration 0: 0.566667
# epoch:  1
# Cost after iteration 1: 0.690050
# Accuracy after iteration 1: 0.450000
# epoch:  2
# Cost after iteration 2: 0.684743
# Accuracy after iteration 2: 0.416667
# epoch:  3
# Cost after iteration 3: 0.700879
# Accuracy after iteration 3: 0.400000
# epoch:  4
# Cost after iteration 4: 0.702798
# Accuracy after iteration 4: 0.350000
# epoch:  5
# Cost after iteration 5: 0.749503
# Accuracy after iteration 5: 0.433333
# epoch:  6
# Cost after iteration 6: 0.703639
# Accuracy after iteration 6: 0.433333
# epoch:  7
# Cost after iteration 7: 0.710109
# Accuracy after iteration 7: 0.433333
# epoch:  8
# Cost after iteration 8: 0.700986
# Accuracy after iteration 8: 0.483333
# epoch:  9
# Cost after iteration 9: 0.684170
# Accuracy after iteration 9: 0.583333
# epoch:  10
# Cost after iteration 10: 0.682089
# Accuracy after iteration 10: 0.500000
# epoch:  11
# Cost after iteration 11: 0.688616
# Accuracy after iteration 11: 0.466667
# epoch:  12
# Cost after iteration 12: 0.697869
# Accuracy after iteration 12: 0.516667
# epoch:  13
# Cost after iteration 13: 0.685910
# Accuracy after iteration 13: 0.633333
# epoch:  14
# Cost after iteration 14: 0.686084
# Accuracy after iteration 14: 0.683333
# epoch:  15
# Cost after iteration 15: 0.697624
# Accuracy after iteration 15: 0.683333
# epoch:  16
# Cost after iteration 16: 0.694777
# Accuracy after iteration 16: 0.683333
# epoch:  17
# Cost after iteration 17: 0.693186
# Accuracy after iteration 17: 0.666667
# epoch:  18
# Cost after iteration 18: 0.685857
# Accuracy after iteration 18: 0.683333
# epoch:  19
# Cost after iteration 19: 0.701992
# Accuracy after iteration 19: 0.683333

# %%
pred_test = predict(X_train, y_train, model, 2)
pred_val = predict(X_val, y_val, model, 2)
# Out:
# Accuracy: 0.5388888888888889
# Accuracy: 0.6833333333333333

# %%
pred_test = predict(X_test, None, model, 2)
output["basic_pred_test"] = pred_test[0].astype(int)

basic_model_layers = []
basic_model_parameters = []
for layer in model.layers:
    basic_model_layers.append(layer.name)
    if(layer.name=="conv" or layer.name=="dense" or layer.name=="maxpool"):
        basic_model_parameters.append(layer.parameters)
output["basic_model_layers"] = basic_model_layers
output["basic_model_parameters"] = basic_model_parameters

# %% [markdown]
# # 8. Advanced implementation
# In this part, you will practice how to build a model by **Tensorflow**, and you finally can use GPU to accelerate the training process☺️. You can import any packages in the advanced part.
#
# **Exercise**: Implement a binary classifier by Tensorflow. You will get 15% if your prediction achieves accuracy greater than 0.7 in testing data. The rest 10% will be graded by your rank.
#
# Except you have to build the model by Tensorflow, there is no limitation in this part. You can try different model architectures, optimization parametes and image augmentation methods to get good performance.

# %%
# import some tensorflow packages to help you build the model
import tensorflow as tf
from tensorflow.keras import layers, models

# import other packages here

# %%
# GRADED CODE: Advanced implementation
### Data preprocess & augmentation ###
if y_train.shape[0] == 1:
    y_train = np.transpose(y_train)
    if validation:
        y_val = np.transpose(y_val)
print(y_train.shape)
print(y_val.shape)
#You may have to adjust the shape of y_train
# Out:
# (540, 1)
# (60, 1)

# %%
# GRADED CODE: Advanced implementation
### Start training ###
model = tf.keras.models.Sequential([
    tf.keras.layers.Conv2D(16, (4, 4), 2, padding = 'same', activation = 'relu', input_shape = (32, 32, 1)),
    tf.keras.layers.MaxPooling2D(2, 2),
    tf.keras.layers.Conv2D(16, (3, 3), padding = 'same', activation='relu'),
    tf.keras.layers.MaxPooling2D(2, 2),
    tf.keras.layers.Flatten(),
    tf.keras.layers.Dense(64, activation='relu'),
    tf.keras.layers.Dense(16, activation='relu'),
    tf.keras.layers.Dense(4, activation='relu'),
    tf.keras.layers.Dense(1, activation='sigmoid') 
])
model.summary()
model.compile(optimizer = 'adam', loss='binary_crossentropy', metrics = ['accuracy'])
history = model.fit(X_train, y_train, epochs = 1000, validation_data = (X_val, y_val))
plt.plot(np.squeeze(history.history['loss']))
plt.ylabel('cost')
plt.xlabel('iterations')
plt.show()
plt.plot(np.squeeze(history.history['val_accuracy']))
plt.ylabel('accuracy')
plt.xlabel('iterations')
plt.show()

print(np.max(history.history['val_accuracy']))
model.evaluate(X_val, y_val)
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 16, 16, 16)        272
#
#  max_pooling2d (MaxPooling2D  (None, 8, 8, 16)         0
#  )
#
#  conv2d_1 (Conv2D)           (None, 8, 8, 16)          2320
#
#  max_pooling2d_1 (MaxPooling  (None, 4, 4, 16)         0
#  2D)
#
#  flatten (Flatten)           (None, 256)               0
#
#  dense (Dense)               (None, 64)                16448
#
#  dense_1 (Dense)             (None, 16)                1040
#
#  dense_2 (Dense)             (None, 4)                 68
#
#  dense_3 (Dense)             (None, 1)                 5
#
# =================================================================
# Total params: 20,153
# Trainable params: 20,153
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/1000
# 17/17 [==============================] - 1s 19ms/step - loss: 0.6872 - accuracy: 0.5407 - val_loss: 0.6839 - val_accuracy: 0.5667
# Epoch 2/1000
# 17/17 [==============================] - 0s 8ms/step - loss: 0.6775 - accuracy: 0.5537 - val_loss: 0.6725 - val_accuracy: 0.6833
# Epoch 3/1000
# 17/17 [==============================] - 0s 8ms/step - loss: 0.6630 - accuracy: 0.6111 - val_loss: 0.6935 - val_accuracy: 0.4333
# Epoch 4/1000
# 17/17 [==============================] - 0s 8ms/step - loss: 0.6329 - accuracy: 0.6981 - val_loss: 0.6638 - val_accuracy: 0.5167
# Epoch 5/1000
# 17/17 [==============================] - 0s 8ms/step - loss: 0.5922 - accuracy: 0.7074 - val_loss: 0.5816 - val_accuracy: 0.7500
# Epoch 6/1000
# 17/17 [==============================] - 0s 8ms/step - loss: 0.5270 - accuracy: 0.7704 - val_loss: 0.5248 - val_accuracy: 0.7833
# Epoch 7/1000
# 17/17 [==============================] - 0s 8ms/step - loss: 0.4956 - accuracy: 0.7759 - val_loss: 0.6211 - val_accuracy: 0.6833
# Epoch 8/1000
# 17/17 [==============================] - 0s 8ms/step - loss: 0.5151 - accuracy: 0.7593 - val_loss: 0.5026 - val_accuracy: 0.7833
# Epoch 9/1000
# 17/17 [==============================] - 0s 8ms/step - loss: 0.4592 - accuracy: 0.8056 - val_loss: 0.4976 - val_accuracy: 0.7833
# Epoch 10/1000
# 17/17 [==============================] - 0s 8ms/step - loss: 0.4506 - accuracy: 0.8222 - val_loss: 0.5449 - val_accuracy: 0.7833
# Epoch 11/1000
# 17/17 [==============================] - 0s 8ms/step - loss: 0.4426 - accuracy: 0.8259 - val_loss: 0.5102 - val_accuracy: 0.7500
# Epoch 12/1000
# 17/17 [==============================] - 0s 8ms/step - loss: 0.4425 - accuracy: 0.8222 - val_loss: 0.5278 - val_accuracy: 0.7833
# Epoch 13/1000
# 17/17 [==============================] - 0s 7ms/step - loss: 0.4469 - accuracy: 0.8130 - val_loss: 0.5040 - val_accuracy: 0.7833
# Epoch 14/1000
# 17/17 [==============================] - 0s 8ms/step - loss: 0.4237 - accuracy: 0.8259 - val_loss: 0.5069 - val_accuracy: 0.8000
# Epoch 15/1000
# 17/17 [==============================] - 0s 8ms/step - loss: 0.4214 - accuracy: 0.8333 - val_loss: 0.5005 - val_accuracy: 0.8000
# Epoch 16/1000
# 17/17 [==============================] - 0s 8ms/step - loss: 0.4196 - accuracy: 0.8315 - val_loss: 0.5066 - val_accuracy: 0.7667
# Epoch 17/1000
# 17/17 [==============================] - 0s 8ms/step - loss: 0.4102 - accuracy: 0.8407 - val_loss: 0.5037 - val_accuracy: 0.8000
# Epoch 18/1000
# 17/17 [==============================] - 0s 8ms/step - loss: 0.4258 - accuracy: 0.8111 - val_loss: 0.6040 - val_accuracy: 0.7500
# Epoch 19/1000
# 17/17 [==============================] - 0s 8ms/step - loss: 0.4370 - accuracy: 0.8259 - val_loss: 0.5308 - val_accuracy: 0.8000
# Epoch 20/1000
# 17/17 [==============================] - 0s 8ms/step - loss: 0.4074 - accuracy: 0.8370 - val_loss: 0.4856 - val_accuracy: 0.8167
# Epoch 21/1000
# 17/17 [==============================] - 0s 8ms/step - loss: 0.3999 - accuracy: 0.8481 - val_loss: 0.4948 - val_accuracy: 0.7667
# Epoch 22/1000
# 17/17 [==============================] - 0s 8ms/step - loss: 0.4000 - accuracy: 0.8481 - val_loss: 0.5188 - val_accuracy: 0.7833
# Epoch 23/1000
# 17/17 [==============================] - 0s 8ms/step - loss: 0.4016 - accuracy: 0.8389 - val_loss: 0.4906 - val_accuracy: 0.8167
# Epoch 24/1000
# 17/17 [==============================] - 0s 8ms/step - loss: 0.3968 - accuracy: 0.8352 - val_loss: 0.5080 - val_accuracy: 0.7500
# Epoch 25/1000
# 17/17 [==============================] - 0s 8ms/step - loss: 0.4198 - accuracy: 0.8204 - val_loss: 0.5335 - val_accuracy: 0.7167
# Epoch 26/1000
# 17/17 [==============================] - 0s 8ms/step - loss: 0.4009 - accuracy: 0.8426 - val_loss: 0.5048 - val_accuracy: 0.8167
# Epoch 27/1000
# 17/17 [==============================] - 0s 8ms/step - loss: 0.3895 - accuracy: 0.8463 - val_loss: 0.4990 - val_accuracy: 0.7833
# Epoch 28/1000
# 17/17 [==============================] - 0s 8ms/step - loss: 0.3889 - accuracy: 0.8500 - val_loss: 0.5014 - val_accuracy: 0.7500
# Epoch 29/1000
# 17/17 [==============================] - 0s 8ms/step - loss: 0.3812 - accuracy: 0.8519 - val_loss: 0.5236 - val_accuracy: 0.8167
# Epoch 30/1000
# 17/17 [==============================] - 0s 8ms/step - loss: 0.3849 - accuracy: 0.8481 - val_loss: 0.5171 - val_accuracy: 0.8167
# Epoch 31/1000
# 17/17 [==============================] - 0s 7ms/step - loss: 0.3716 - accuracy: 0.8574 - val_loss: 0.5027 - val_accuracy: 0.8000
# Epoch 32/1000
# 17/17 [==============================] - 0s 9ms/step - loss: 0.3742 - accuracy: 0.8611 - val_loss: 0.5112 - val_accuracy: 0.8167
# Epoch 33/1000
# 17/17 [==============================] - 0s 8ms/step - loss: 0.3773 - accuracy: 0.8444 - val_loss: 0.5056 - val_accuracy: 0.7667
# Epoch 34/1000
# 17/17 [==============================] - 0s 8ms/step - loss: 0.3679 - accuracy: 0.8444 - val_loss: 0.5058 - val_accuracy: 0.8000
# Epoch 35/1000
# 17/17 [==============================] - 0s 8ms/step - loss: 0.3621 - accuracy: 0.8630 - val_loss: 0.4930 - val_accuracy: 0.8000
# Epoch 36/1000
# 17/17 [==============================] - 0s 8ms/step - loss: 0.3611 - accuracy: 0.8593 - val_loss: 0.5056 - val_accuracy: 0.8000
# Epoch 37/1000
# 17/17 [==============================] - 0s 8ms/step - loss: 0.3604 - accuracy: 0.8556 - val_loss: 0.5097 - val_accuracy: 0.8000
# Epoch 38/1000
# 17/17 [==============================] - 0s 9ms/step - loss: 0.3624 - accuracy: 0.8574 - val_loss: 0.5051 - val_accuracy: 0.7833
# Epoch 39/1000
# 17/17 [==============================] - 0s 8ms/step - loss: 0.3673 - accuracy: 0.8611 - val_loss: 0.5170 - val_accuracy: 0.8000
# Epoch 40/1000
# 17/17 [==============================] - 0s 7ms/step - loss: 0.3633 - accuracy: 0.8648 - val_loss: 0.5103 - val_accuracy: 0.7833
# Epoch 41/1000
# 17/17 [==============================] - 0s 7ms/step - loss: 0.3531 - accuracy: 0.8556 - val_loss: 0.5210 - val_accuracy: 0.7500
# Epoch 42/1000
# 17/17 [==============================] - 0s 8ms/step - loss: 0.3457 - accuracy: 0.8704 - val_loss: 0.5180 - val_accuracy: 0.8167
# Epoch 43/1000
# 17/17 [==============================] - 0s 7ms/step - loss: 0.3465 - accuracy: 0.8611 - val_loss: 0.5138 - val_accuracy: 0.7667
# Epoch 44/1000
# 17/17 [==============================] - 0s 8ms/step - loss: 0.3484 - accuracy: 0.8704 - val_loss: 0.5206 - val_accuracy: 0.7833
# Epoch 45/1000
# 17/17 [==============================] - 0s 8ms/step - loss: 0.3385 - accuracy: 0.8704 - val_loss: 0.5116 - val_accuracy: 0.8167
# Epoch 46/1000
# 17/17 [==============================] - 0s 8ms/step - loss: 0.3323 - accuracy: 0.8685 - val_loss: 0.5360 - val_accuracy: 0.8167
# Epoch 47/1000
# 17/17 [==============================] - 0s 7ms/step - loss: 0.3454 - accuracy: 0.8556 - val_loss: 0.5072 - val_accuracy: 0.8000
# Epoch 48/1000
# 17/17 [==============================] - 0s 8ms/step - loss: 0.3472 - accuracy: 0.8630 - val_loss: 0.5306 - val_accuracy: 0.7667
# Epoch 49/1000
# 17/17 [==============================] - 0s 8ms/step - loss: 0.3352 - accuracy: 0.8648 - val_loss: 0.5221 - val_accuracy: 0.7667
# Epoch 50/1000
# 17/17 [==============================] - 0s 8ms/step - loss: 0.3243 - accuracy: 0.8815 - val_loss: 0.5046 - val_accuracy: 0.8000
# Epoch 51/1000
# 17/17 [==============================] - 0s 8ms/step - loss: 0.3231 - accuracy: 0.8759 - val_loss: 0.5372 - val_accuracy: 0.8000
# Epoch 52/1000
# 17/17 [==============================] - 0s 8ms/step - loss: 0.3165 - accuracy: 0.8778 - val_loss: 0.5374 - val_accuracy: 0.8000
# Epoch 53/1000
# 17/17 [==============================] - 0s 8ms/step - loss: 0.3126 - accuracy: 0.8870 - val_loss: 0.5144 - val_accuracy: 0.8000
# Epoch 54/1000
# 17/17 [==============================] - 0s 8ms/step - loss: 0.3001 - accuracy: 0.8870 - val_loss: 0.5201 - val_accuracy: 0.7833
# Epoch 55/1000
# 17/17 [==============================] - 0s 8ms/step - loss: 0.3094 - accuracy: 0.8815 - val_loss: 0.5438 - val_accuracy: 0.7833
# Epoch 56/1000
# 17/17 [==============================] - 0s 8ms/step - loss: 0.3022 - accuracy: 0.8889 - val_loss: 0.5361 - val_accuracy: 0.8167
# Epoch 57/1000
# 17/17 [==============================] - 0s 8ms/step - loss: 0.3103 - accuracy: 0.8889 - val_loss: 0.5527 - val_accuracy: 0.7500
# Epoch 58/1000
# 17/17 [==============================] - 0s 8ms/step - loss: 0.3117 - accuracy: 0.8796 - val_loss: 0.5211 - val_accuracy: 0.8167
# Epoch 59/1000
# 17/17 [==============================] - 0s 8ms/step - loss: 0.2880 - accuracy: 0.8981 - val_loss: 0.5753 - val_accuracy: 0.8167
# Epoch 60/1000
# 17/17 [==============================] - 0s 8ms/step - loss: 0.2870 - accuracy: 0.8963 - val_loss: 0.5169 - val_accuracy: 0.8000
# Epoch 61/1000
# 17/17 [==============================] - 0s 8ms/step - loss: 0.2877 - accuracy: 0.8944 - val_loss: 0.5458 - val_accuracy: 0.7833
# Epoch 62/1000
# 17/17 [==============================] - 0s 8ms/step - loss: 0.2801 - accuracy: 0.9019 - val_loss: 0.5657 - val_accuracy: 0.7667
# Epoch 63/1000
# 17/17 [==============================] - 0s 8ms/step - loss: 0.2813 - accuracy: 0.8963 - val_loss: 0.6231 - val_accuracy: 0.7500
# Epoch 64/1000
# 17/17 [==============================] - 0s 7ms/step - loss: 0.3427 - accuracy: 0.8630 - val_loss: 0.5899 - val_accuracy: 0.7833
# Epoch 65/1000
# 17/17 [==============================] - 0s 7ms/step - loss: 0.3155 - accuracy: 0.8778 - val_loss: 0.5323 - val_accuracy: 0.7500
# Epoch 66/1000
# 17/17 [==============================] - 0s 8ms/step - loss: 0.2763 - accuracy: 0.8981 - val_loss: 0.5381 - val_accuracy: 0.8000
# Epoch 67/1000
# 17/17 [==============================] - 0s 7ms/step - loss: 0.2662 - accuracy: 0.8926 - val_loss: 0.5960 - val_accuracy: 0.8000
# Epoch 68/1000
# 17/17 [==============================] - 0s 8ms/step - loss: 0.2521 - accuracy: 0.9074 - val_loss: 0.6279 - val_accuracy: 0.7667
# Epoch 69/1000
# 17/17 [==============================] - 0s 7ms/step - loss: 0.2729 - accuracy: 0.9037 - val_loss: 0.5858 - val_accuracy: 0.7500
# Epoch 70/1000
# 17/17 [==============================] - 0s 8ms/step - loss: 0.2556 - accuracy: 0.9074 - val_loss: 0.6089 - val_accuracy: 0.7667
# Epoch 71/1000
# 17/17 [==============================] - 0s 8ms/step - loss: 0.2457 - accuracy: 0.9074 - val_loss: 0.5402 - val_accuracy: 0.8000
# Epoch 72/1000
# 17/17 [==============================] - 0s 8ms/step - loss: 0.2417 - accuracy: 0.9056 - val_loss: 0.5714 - val_accuracy: 0.8000
# Epoch 73/1000
# 17/17 [==============================] - 0s 7ms/step - loss: 0.2347 - accuracy: 0.9111 - val_loss: 0.5619 - val_accuracy: 0.7833
# Epoch 74/1000
# 17/17 [==============================] - 0s 7ms/step - loss: 0.2253 - accuracy: 0.9241 - val_loss: 0.5668 - val_accuracy: 0.7667
# Epoch 75/1000
# 17/17 [==============================] - 0s 8ms/step - loss: 0.2269 - accuracy: 0.9222 - val_loss: 0.5685 - val_accuracy: 0.7667
# Epoch 76/1000
# 17/17 [==============================] - 0s 8ms/step - loss: 0.2214 - accuracy: 0.9204 - val_loss: 0.6431 - val_accuracy: 0.7500
# Epoch 77/1000
# 17/17 [==============================] - 0s 8ms/step - loss: 0.2279 - accuracy: 0.9130 - val_loss: 0.5406 - val_accuracy: 0.8000
# Epoch 78/1000
# 17/17 [==============================] - 0s 7ms/step - loss: 0.2266 - accuracy: 0.9148 - val_loss: 0.6718 - val_accuracy: 0.7333
# Epoch 79/1000
# 17/17 [==============================] - 0s 8ms/step - loss: 0.2115 - accuracy: 0.9259 - val_loss: 0.5692 - val_accuracy: 0.7833
# Epoch 80/1000
# 17/17 [==============================] - 0s 7ms/step - loss: 0.2109 - accuracy: 0.9259 - val_loss: 0.5659 - val_accuracy: 0.8167
# Epoch 81/1000
# 17/17 [==============================] - 0s 7ms/step - loss: 0.1900 - accuracy: 0.9389 - val_loss: 0.5692 - val_accuracy: 0.8167
# Epoch 82/1000
# 17/17 [==============================] - 0s 7ms/step - loss: 0.1822 - accuracy: 0.9407 - val_loss: 0.5871 - val_accuracy: 0.8000
# Epoch 83/1000
# 17/17 [==============================] - 0s 7ms/step - loss: 0.1764 - accuracy: 0.9481 - val_loss: 0.5592 - val_accuracy: 0.8000
# Epoch 84/1000
# 17/17 [==============================] - 0s 8ms/step - loss: 0.1816 - accuracy: 0.9407 - val_loss: 0.5900 - val_accuracy: 0.8000
# Epoch 85/1000
# 17/17 [==============================] - 0s 7ms/step - loss: 0.1749 - accuracy: 0.9444 - val_loss: 0.5537 - val_accuracy: 0.8000
# Epoch 86/1000
# 17/17 [==============================] - 0s 7ms/step - loss: 0.1713 - accuracy: 0.9519 - val_loss: 0.6023 - val_accuracy: 0.8167
# Epoch 87/1000
# 17/17 [==============================] - 0s 7ms/step - loss: 0.1695 - accuracy: 0.9444 - val_loss: 0.5818 - val_accuracy: 0.8000
# Epoch 88/1000
# 17/17 [==============================] - 0s 7ms/step - loss: 0.1782 - accuracy: 0.9444 - val_loss: 0.6218 - val_accuracy: 0.8000
# Epoch 89/1000
# 17/17 [==============================] - 0s 7ms/step - loss: 0.1639 - accuracy: 0.9519 - val_loss: 0.6370 - val_accuracy: 0.8167
# Epoch 90/1000
# 17/17 [==============================] - 0s 7ms/step - loss: 0.1587 - accuracy: 0.9537 - val_loss: 0.6378 - val_accuracy: 0.8000
# Epoch 91/1000
# 17/17 [==============================] - 0s 7ms/step - loss: 0.1524 - accuracy: 0.9556 - val_loss: 0.6019 - val_accuracy: 0.8000
# Epoch 92/1000
# 17/17 [==============================] - 0s 7ms/step - loss: 0.1820 - accuracy: 0.9333 - val_loss: 0.6257 - val_accuracy: 0.8333
# Epoch 93/1000
# 17/17 [==============================] - 0s 7ms/step - loss: 0.1730 - accuracy: 0.9352 - val_loss: 0.6026 - val_accuracy: 0.8333
# Epoch 94/1000
# 17/17 [==============================] - 0s 7ms/step - loss: 0.1482 - accuracy: 0.9574 - val_loss: 0.6851 - val_accuracy: 0.7833
# Epoch 95/1000
# 17/17 [==============================] - 0s 7ms/step - loss: 0.1482 - accuracy: 0.9537 - val_loss: 0.6057 - val_accuracy: 0.8000
# Epoch 96/1000
# 17/17 [==============================] - 0s 7ms/step - loss: 0.1422 - accuracy: 0.9611 - val_loss: 0.7051 - val_accuracy: 0.7833
# Epoch 97/1000
# 17/17 [==============================] - 0s 7ms/step - loss: 0.1528 - accuracy: 0.9481 - val_loss: 0.6726 - val_accuracy: 0.7500
# Epoch 98/1000
# 17/17 [==============================] - 0s 7ms/step - loss: 0.1507 - accuracy: 0.9556 - val_loss: 0.6880 - val_accuracy: 0.7833
# Epoch 99/1000
# 17/17 [==============================] - 0s 7ms/step - loss: 0.1455 - accuracy: 0.9537 - val_loss: 0.6287 - val_accuracy: 0.8167
# Epoch 100/1000
# 17/17 [==============================] - 0s 7ms/step - loss: 0.1376 - accuracy: 0.9611 - val_loss: 0.7193 - val_accuracy: 0.8000
# Epoch 101/1000
# 17/17 [==============================] - 0s 7ms/step - loss: 0.1319 - accuracy: 0.9611 - val_loss: 0.6626 - val_accuracy: 0.8000
# Epoch 102/1000
# 17/17 [==============================] - 0s 7ms/step - loss: 0.1313 - accuracy: 0.9556 - val_loss: 0.6480 - val_accuracy: 0.8000
# Epoch 103/1000
# 17/17 [==============================] - 0s 7ms/step - loss: 0.1363 - accuracy: 0.9537 - val_loss: 0.7244 - val_accuracy: 0.7833
# Epoch 104/1000
# 17/17 [==============================] - 0s 8ms/step - loss: 0.1503 - accuracy: 0.9481 - val_loss: 0.8183 - val_accuracy: 0.7833
# Epoch 105/1000
# 17/17 [==============================] - 0s 7ms/step - loss: 0.1726 - accuracy: 0.9315 - val_loss: 0.6920 - val_accuracy: 0.7667
# Epoch 106/1000
# 17/17 [==============================] - 0s 7ms/step - loss: 0.1874 - accuracy: 0.9222 - val_loss: 0.6603 - val_accuracy: 0.8000
# Epoch 107/1000
# 17/17 [==============================] - 0s 7ms/step - loss: 0.1460 - accuracy: 0.9481 - val_loss: 0.6546 - val_accuracy: 0.7667
# Epoch 108/1000
# 17/17 [==============================] - 0s 7ms/step - loss: 0.1412 - accuracy: 0.9481 - val_loss: 0.7947 - val_accuracy: 0.8000
# Epoch 109/1000
# 17/17 [==============================] - 0s 7ms/step - loss: 0.1676 - accuracy: 0.9389 - val_loss: 0.7483 - val_accuracy: 0.7833
# Epoch 110/1000
# 17/17 [==============================] - 0s 7ms/step - loss: 0.1679 - accuracy: 0.9333 - val_loss: 0.6157 - val_accuracy: 0.8000
# Epoch 111/1000
# 17/17 [==============================] - 0s 7ms/step - loss: 0.1420 - accuracy: 0.9463 - val_loss: 0.6540 - val_accuracy: 0.8167
# Epoch 112/1000
# 17/17 [==============================] - 0s 7ms/step - loss: 0.1268 - accuracy: 0.9574 - val_loss: 0.7149 - val_accuracy: 0.8167
# Epoch 113/1000
# 17/17 [==============================] - 0s 7ms/step - loss: 0.1245 - accuracy: 0.9574 - val_loss: 0.7453 - val_accuracy: 0.8000
# Epoch 114/1000
# 17/17 [==============================] - 0s 7ms/step - loss: 0.1220 - accuracy: 0.9648 - val_loss: 0.7805 - val_accuracy: 0.7667
# Epoch 115/1000
# 17/17 [==============================] - 0s 7ms/step - loss: 0.1105 - accuracy: 0.9648 - val_loss: 0.7359 - val_accuracy: 0.8167
# Epoch 116/1000
# 17/17 [==============================] - 0s 7ms/step - loss: 0.1051 - accuracy: 0.9685 - val_loss: 0.7298 - val_accuracy: 0.8167
# Epoch 117/1000
# 17/17 [==============================] - 0s 7ms/step - loss: 0.1057 - accuracy: 0.9667 - val_loss: 0.6914 - val_accuracy: 0.8167
# Epoch 118/1000
# 17/17 [==============================] - 0s 7ms/step - loss: 0.0959 - accuracy: 0.9667 - val_loss: 0.7690 - val_accuracy: 0.8167
# Epoch 119/1000
# 17/17 [==============================] - 0s 7ms/step - loss: 0.0970 - accuracy: 0.9704 - val_loss: 0.6612 - val_accuracy: 0.8333
# Epoch 120/1000
# 17/17 [==============================] - 0s 7ms/step - loss: 0.0949 - accuracy: 0.9685 - val_loss: 0.8410 - val_accuracy: 0.8167
# Epoch 121/1000
# 17/17 [==============================] - 0s 7ms/step - loss: 0.1023 - accuracy: 0.9667 - val_loss: 0.7246 - val_accuracy: 0.8000
# Epoch 122/1000
# 17/17 [==============================] - 0s 7ms/step - loss: 0.0951 - accuracy: 0.9648 - val_loss: 0.7227 - val_accuracy: 0.8000
# Epoch 123/1000
# 17/17 [==============================] - 0s 7ms/step - loss: 0.1148 - accuracy: 0.9593 - val_loss: 0.8986 - val_accuracy: 0.7667
# Epoch 124/1000
# 17/17 [==============================] - 0s 7ms/step - loss: 0.1182 - accuracy: 0.9500 - val_loss: 0.7711 - val_accuracy: 0.7833
# Epoch 125/1000
# 17/17 [==============================] - 0s 7ms/step - loss: 0.1003 - accuracy: 0.9685 - val_loss: 0.7269 - val_accuracy: 0.8167
# Epoch 126/1000
# 17/17 [==============================] - 0s 8ms/step - loss: 0.0935 - accuracy: 0.9704 - val_loss: 0.7332 - val_accuracy: 0.8167
# Epoch 127/1000
# 17/17 [==============================] - 0s 7ms/step - loss: 0.0802 - accuracy: 0.9778 - val_loss: 0.9262 - val_accuracy: 0.7833
# Epoch 128/1000
# 17/17 [==============================] - 0s 7ms/step - loss: 0.0918 - accuracy: 0.9722 - val_loss: 1.0681 - val_accuracy: 0.7667
# Epoch 129/1000
# 17/17 [==============================] - 0s 7ms/step - loss: 0.0914 - accuracy: 0.9611 - val_loss: 0.8028 - val_accuracy: 0.8000
# Epoch 130/1000
# 17/17 [==============================] - 0s 7ms/step - loss: 0.0995 - accuracy: 0.9648 - val_loss: 1.0154 - val_accuracy: 0.8000
# Epoch 131/1000
# 17/17 [==============================] - 0s 7ms/step - loss: 0.1495 - accuracy: 0.9426 - val_loss: 0.8703 - val_accuracy: 0.7667
# Epoch 132/1000
# 17/17 [==============================] - 0s 7ms/step - loss: 0.1552 - accuracy: 0.9333 - val_loss: 0.8090 - val_accuracy: 0.7667
# Epoch 133/1000
# 17/17 [==============================] - 0s 7ms/step - loss: 0.1506 - accuracy: 0.9500 - val_loss: 0.8230 - val_accuracy: 0.8167
# Epoch 134/1000
# 17/17 [==============================] - 0s 7ms/step - loss: 0.0920 - accuracy: 0.9667 - val_loss: 0.8331 - val_accuracy: 0.8167
# Epoch 135/1000
# 17/17 [==============================] - 0s 7ms/step - loss: 0.0900 - accuracy: 0.9704 - val_loss: 0.8042 - val_accuracy: 0.8333
# Epoch 136/1000
# 17/17 [==============================] - 0s 8ms/step - loss: 0.0730 - accuracy: 0.9759 - val_loss: 0.8231 - val_accuracy: 0.8167
# Epoch 137/1000
# 17/17 [==============================] - 0s 7ms/step - loss: 0.0756 - accuracy: 0.9778 - val_loss: 0.8686 - val_accuracy: 0.8000
# Epoch 138/1000
# 17/17 [==============================] - 0s 7ms/step - loss: 0.0675 - accuracy: 0.9778 - val_loss: 0.7697 - val_accuracy: 0.8000
# Epoch 139/1000
# 17/17 [==============================] - 0s 7ms/step - loss: 0.1086 - accuracy: 0.9537 - val_loss: 1.0615 - val_accuracy: 0.8000
# Epoch 140/1000
# 17/17 [==============================] - 0s 7ms/step - loss: 0.0733 - accuracy: 0.9722 - val_loss: 0.9507 - val_accuracy: 0.8333
# Epoch 141/1000
# 17/17 [==============================] - 0s 7ms/step - loss: 0.0610 - accuracy: 0.9833 - val_loss: 0.8951 - val_accuracy: 0.8167
# Epoch 142/1000
# 17/17 [==============================] - 0s 7ms/step - loss: 0.0543 - accuracy: 0.9815 - val_loss: 0.9128 - val_accuracy: 0.8333
# Epoch 143/1000
# 17/17 [==============================] - 0s 7ms/step - loss: 0.0640 - accuracy: 0.9796 - val_loss: 0.9722 - val_accuracy: 0.8000
# Epoch 144/1000
# 17/17 [==============================] - 0s 7ms/step - loss: 0.0813 - accuracy: 0.9685 - val_loss: 0.9191 - val_accuracy: 0.8000
# Epoch 145/1000
# 17/17 [==============================] - 0s 8ms/step - loss: 0.0612 - accuracy: 0.9759 - val_loss: 0.9068 - val_accuracy: 0.7833
# Epoch 146/1000
# 17/17 [==============================] - 0s 7ms/step - loss: 0.0548 - accuracy: 0.9852 - val_loss: 1.0057 - val_accuracy: 0.8167
# Epoch 147/1000
# 17/17 [==============================] - 0s 7ms/step - loss: 0.0564 - accuracy: 0.9833 - val_loss: 0.9236 - val_accuracy: 0.8167
# Epoch 148/1000
# 17/17 [==============================] - 0s 7ms/step - loss: 0.1021 - accuracy: 0.9611 - val_loss: 0.9463 - val_accuracy: 0.8167
# Epoch 149/1000
# 17/17 [==============================] - 0s 7ms/step - loss: 0.0546 - accuracy: 0.9852 - val_loss: 0.9969 - val_accuracy: 0.7667
# Epoch 150/1000
# 17/17 [==============================] - 0s 7ms/step - loss: 0.0610 - accuracy: 0.9815 - val_loss: 0.9458 - val_accuracy: 0.8000
# Epoch 151/1000
# 17/17 [==============================] - 0s 7ms/step - loss: 0.0625 - accuracy: 0.9778 - val_loss: 1.0303 - val_accuracy: 0.8000
# Epoch 152/1000
# 17/17 [==============================] - 0s 7ms/step - loss: 0.0606 - accuracy: 0.9833 - val_loss: 1.1724 - val_accuracy: 0.7833
# Epoch 153/1000
# 17/17 [==============================] - 0s 7ms/step - loss: 0.0653 - accuracy: 0.9815 - val_loss: 1.0610 - val_accuracy: 0.7667
# Epoch 154/1000
# 17/17 [==============================] - 0s 7ms/step - loss: 0.0643 - accuracy: 0.9759 - val_loss: 1.0571 - val_accuracy: 0.8167
# Epoch 155/1000
# 17/17 [==============================] - 0s 7ms/step - loss: 0.0555 - accuracy: 0.9778 - val_loss: 1.0918 - val_accuracy: 0.8333
# Epoch 156/1000
# 17/17 [==============================] - 0s 7ms/step - loss: 0.0493 - accuracy: 0.9907 - val_loss: 1.0190 - val_accuracy: 0.7667
# Epoch 157/1000
# 17/17 [==============================] - 0s 7ms/step - loss: 0.0765 - accuracy: 0.9759 - val_loss: 1.0546 - val_accuracy: 0.8333
# Epoch 158/1000
# 17/17 [==============================] - 0s 7ms/step - loss: 0.0619 - accuracy: 0.9815 - val_loss: 1.0324 - val_accuracy: 0.8000
# Epoch 159/1000
# 17/17 [==============================] - 0s 7ms/step - loss: 0.0442 - accuracy: 0.9907 - val_loss: 1.1000 - val_accuracy: 0.8167
# Epoch 160/1000
# 17/17 [==============================] - 0s 8ms/step - loss: 0.0997 - accuracy: 0.9667 - val_loss: 1.0239 - val_accuracy: 0.8000
# Epoch 161/1000
# 17/17 [==============================] - 0s 7ms/step - loss: 0.0629 - accuracy: 0.9741 - val_loss: 1.0383 - val_accuracy: 0.8333
# Epoch 162/1000
# 17/17 [==============================] - 0s 7ms/step - loss: 0.0484 - accuracy: 0.9870 - val_loss: 1.2530 - val_accuracy: 0.7667
# Epoch 163/1000
# 17/17 [==============================] - 0s 7ms/step - loss: 0.0478 - accuracy: 0.9833 - val_loss: 1.0744 - val_accuracy: 0.8167
# Epoch 164/1000
# 17/17 [==============================] - 0s 7ms/step - loss: 0.0756 - accuracy: 0.9667 - val_loss: 1.4753 - val_accuracy: 0.6833
# Epoch 165/1000
# 17/17 [==============================] - 0s 7ms/step - loss: 0.1927 - accuracy: 0.9370 - val_loss: 1.0160 - val_accuracy: 0.7000
# Epoch 166/1000
# 17/17 [==============================] - 0s 7ms/step - loss: 0.1103 - accuracy: 0.9574 - val_loss: 1.0204 - val_accuracy: 0.8000
# Epoch 167/1000
# 17/17 [==============================] - 0s 7ms/step - loss: 0.0847 - accuracy: 0.9667 - val_loss: 0.9731 - val_accuracy: 0.7667
# Epoch 168/1000
# 17/17 [==============================] - 0s 7ms/step - loss: 0.0445 - accuracy: 0.9907 - val_loss: 1.1301 - val_accuracy: 0.7833
# Epoch 169/1000
# 17/17 [==============================] - 0s 7ms/step - loss: 0.0344 - accuracy: 0.9926 - val_loss: 1.0855 - val_accuracy: 0.7500
# Epoch 170/1000
# 17/17 [==============================] - 0s 7ms/step - loss: 0.0311 - accuracy: 0.9926 - val_loss: 1.1346 - val_accuracy: 0.8333
# Epoch 171/1000
# 17/17 [==============================] - 0s 7ms/step - loss: 0.0273 - accuracy: 0.9944 - val_loss: 1.0862 - val_accuracy: 0.8000
# Epoch 172/1000
# 17/17 [==============================] - 0s 7ms/step - loss: 0.0231 - accuracy: 0.9963 - val_loss: 1.1397 - val_accuracy: 0.8000
# Epoch 173/1000
# 17/17 [==============================] - 0s 8ms/step - loss: 0.0236 - accuracy: 0.9963 - val_loss: 1.1101 - val_accuracy: 0.8333
# Epoch 174/1000
# 17/17 [==============================] - 0s 7ms/step - loss: 0.0202 - accuracy: 0.9981 - val_loss: 1.1119 - val_accuracy: 0.8000
# Epoch 175/1000
# 17/17 [==============================] - 0s 7ms/step - loss: 0.0183 - accuracy: 0.9981 - val_loss: 1.0909 - val_accuracy: 0.8000
# Epoch 176/1000
# 17/17 [==============================] - 0s 7ms/step - loss: 0.0178 - accuracy: 0.9981 - val_loss: 1.1408 - val_accuracy: 0.8167
# Epoch 177/1000
# 17/17 [==============================] - 0s 8ms/step - loss: 0.0199 - accuracy: 0.9963 - val_loss: 1.1492 - val_accuracy: 0.8000
# Epoch 178/1000
# 17/17 [==============================] - 0s 8ms/step - loss: 0.0163 - accuracy: 0.9981 - val_loss: 1.1362 - val_accuracy: 0.8000
# Epoch 179/1000
# 17/17 [==============================] - 0s 7ms/step - loss: 0.0144 - accuracy: 0.9981 - val_loss: 1.1359 - val_accuracy: 0.7833
# Epoch 180/1000
# 17/17 [==============================] - 0s 7ms/step - loss: 0.0141 - accuracy: 0.9981 - val_loss: 1.1306 - val_accuracy: 0.8000
# Epoch 181/1000
# 17/17 [==============================] - 0s 8ms/step - loss: 0.0135 - accuracy: 0.9981 - val_loss: 1.1348 - val_accuracy: 0.7833
# Epoch 182/1000
# 17/17 [==============================] - 0s 8ms/step - loss: 0.0133 - accuracy: 0.9981 - val_loss: 1.1326 - val_accuracy: 0.8000
# Epoch 183/1000
# 17/17 [==============================] - 0s 7ms/step - loss: 0.0124 - accuracy: 0.9981 - val_loss: 1.1501 - val_accuracy: 0.8000
# Epoch 184/1000
# 17/17 [==============================] - 0s 7ms/step - loss: 0.0131 - accuracy: 0.9981 - val_loss: 1.1826 - val_accuracy: 0.8167
# Epoch 185/1000
# 17/17 [==============================] - 0s 7ms/step - loss: 0.0102 - accuracy: 0.9981 - val_loss: 1.1808 - val_accuracy: 0.8167
# Epoch 186/1000
# 17/17 [==============================] - 0s 7ms/step - loss: 0.0102 - accuracy: 0.9981 - val_loss: 1.1907 - val_accuracy: 0.8167
# Epoch 187/1000
# 17/17 [==============================] - 0s 7ms/step - loss: 0.0086 - accuracy: 0.9981 - val_loss: 1.1899 - val_accuracy: 0.8000
# Epoch 188/1000
# 17/17 [==============================] - 0s 7ms/step - loss: 0.0092 - accuracy: 1.0000 - val_loss: 1.2071 - val_accuracy: 0.8167
# Epoch 189/1000
# 17/17 [==============================] - 0s 7ms/step - loss: 0.0054 - accuracy: 1.0000 - val_loss: 1.2158 - val_accuracy: 0.8333
# Epoch 190/1000
# 17/17 [==============================] - 0s 8ms/step - loss: 0.0051 - accuracy: 1.0000 - val_loss: 1.2493 - val_accuracy: 0.8167
# Epoch 191/1000
# 17/17 [==============================] - 0s 7ms/step - loss: 0.0068 - accuracy: 1.0000 - val_loss: 1.2268 - val_accuracy: 0.8167
# Epoch 192/1000
# 17/17 [==============================] - 0s 7ms/step - loss: 0.0051 - accuracy: 1.0000 - val_loss: 1.2587 - val_accuracy: 0.8333
# Epoch 193/1000
# 17/17 [==============================] - 0s 7ms/step - loss: 0.0050 - accuracy: 1.0000 - val_loss: 1.2565 - val_accuracy: 0.8333
# Epoch 194/1000
# 17/17 [==============================] - 0s 7ms/step - loss: 0.0050 - accuracy: 1.0000 - val_loss: 1.2592 - val_accuracy: 0.8333
# Epoch 195/1000
# 17/17 [==============================] - 0s 7ms/step - loss: 0.0042 - accuracy: 1.0000 - val_loss: 1.2610 - val_accuracy: 0.8167
# Epoch 196/1000
# 17/17 [==============================] - 0s 8ms/step - loss: 0.0033 - accuracy: 1.0000 - val_loss: 1.2713 - val_accuracy: 0.8333
# Epoch 197/1000
# 17/17 [==============================] - 0s 7ms/step - loss: 0.0031 - accuracy: 1.0000 - val_loss: 1.2792 - val_accuracy: 0.8333
# Epoch 198/1000
# 17/17 [==============================] - 0s 8ms/step - loss: 0.0031 - accuracy: 1.0000 - val_loss: 1.2858 - val_accuracy: 0.8167
# Epoch 199/1000
# 17/17 [==============================] - 0s 7ms/step - loss: 0.0031 - accuracy: 1.0000 - val_loss: 1.2799 - val_accuracy: 0.8167
# Epoch 200/1000
# 17/17 [==============================] - 0s 7ms/step - loss: 0.0038 - accuracy: 1.0000 - val_loss: 1.2978 - val_accuracy: 0.8167
# Epoch 201/1000
# 17/17 [==============================] - 0s 7ms/step - loss: 0.0041 - accuracy: 1.0000 - val_loss: 1.3078 - val_accuracy: 0.8333
# Epoch 202/1000
# 17/17 [==============================] - 0s 7ms/step - loss: 0.0028 - accuracy: 1.0000 - val_loss: 1.3007 - val_accuracy: 0.8333
# Epoch 203/1000
# 17/17 [==============================] - 0s 8ms/step - loss: 0.0024 - accuracy: 1.0000 - val_loss: 1.3146 - val_accuracy: 0.8167
# Epoch 204/1000
# 17/17 [==============================] - 0s 7ms/step - loss: 0.0022 - accuracy: 1.0000 - val_loss: 1.3298 - val_accuracy: 0.8167
# Epoch 205/1000
# 17/17 [==============================] - 0s 7ms/step - loss: 0.0025 - accuracy: 1.0000 - val_loss: 1.3210 - val_accuracy: 0.8333
# Epoch 206/1000
# 17/17 [==============================] - 0s 7ms/step - loss: 0.0021 - accuracy: 1.0000 - val_loss: 1.3401 - val_accuracy: 0.8167
# Epoch 207/1000
# 17/17 [==============================] - 0s 8ms/step - loss: 0.0021 - accuracy: 1.0000 - val_loss: 1.3448 - val_accuracy: 0.8333
# Epoch 208/1000
# 17/17 [==============================] - 0s 7ms/step - loss: 0.0019 - accuracy: 1.0000 - val_loss: 1.3563 - val_accuracy: 0.8167
# Epoch 209/1000
# 17/17 [==============================] - 0s 7ms/step - loss: 0.0018 - accuracy: 1.0000 - val_loss: 1.3563 - val_accuracy: 0.8167
# Epoch 210/1000
# 17/17 [==============================] - 0s 7ms/step - loss: 0.0017 - accuracy: 1.0000 - val_loss: 1.3737 - val_accuracy: 0.8167
# Epoch 211/1000
# 17/17 [==============================] - 0s 7ms/step - loss: 0.0018 - accuracy: 1.0000 - val_loss: 1.3716 - val_accuracy: 0.8167
# Epoch 212/1000
# 17/17 [==============================] - 0s 7ms/step - loss: 0.0017 - accuracy: 1.0000 - val_loss: 1.3905 - val_accuracy: 0.8167
# Epoch 213/1000
# 17/17 [==============================] - 0s 8ms/step - loss: 0.0018 - accuracy: 1.0000 - val_loss: 1.3853 - val_accuracy: 0.8167
# Epoch 214/1000
# 17/17 [==============================] - 0s 7ms/step - loss: 0.0016 - accuracy: 1.0000 - val_loss: 1.3880 - val_accuracy: 0.8167
# Epoch 215/1000
# 17/17 [==============================] - 0s 7ms/step - loss: 0.0015 - accuracy: 1.0000 - val_loss: 1.3927 - val_accuracy: 0.8167
# Epoch 216/1000
# 17/17 [==============================] - 0s 7ms/step - loss: 0.0015 - accuracy: 1.0000 - val_loss: 1.4062 - val_accuracy: 0.8167
# Epoch 217/1000
# 17/17 [==============================] - 0s 7ms/step - loss: 0.0015 - accuracy: 1.0000 - val_loss: 1.4078 - val_accuracy: 0.8167
# Epoch 218/1000
# 17/17 [==============================] - 0s 7ms/step - loss: 0.0013 - accuracy: 1.0000 - val_loss: 1.4097 - val_accuracy: 0.8333
# Epoch 219/1000
# 17/17 [==============================] - 0s 7ms/step - loss: 0.0013 - accuracy: 1.0000 - val_loss: 1.4170 - val_accuracy: 0.8167
# Epoch 220/1000
# 17/17 [==============================] - 0s 7ms/step - loss: 0.0013 - accuracy: 1.0000 - val_loss: 1.4236 - val_accuracy: 0.8167
# Epoch 221/1000
# 17/17 [==============================] - 0s 7ms/step - loss: 0.0013 - accuracy: 1.0000 - val_loss: 1.4246 - val_accuracy: 0.8167
# Epoch 222/1000
# 17/17 [==============================] - 0s 7ms/step - loss: 0.0013 - accuracy: 1.0000 - val_loss: 1.4333 - val_accuracy: 0.8167
# Epoch 223/1000
# 17/17 [==============================] - 0s 7ms/step - loss: 0.0012 - accuracy: 1.0000 - val_loss: 1.4393 - val_accuracy: 0.8167
# Epoch 224/1000
# 17/17 [==============================] - 0s 7ms/step - loss: 0.0012 - accuracy: 1.0000 - val_loss: 1.4331 - val_accuracy: 0.8167
# Epoch 225/1000
# 17/17 [==============================] - 0s 7ms/step - loss: 0.0011 - accuracy: 1.0000 - val_loss: 1.4411 - val_accuracy: 0.8167
# Epoch 226/1000
# 17/17 [==============================] - 0s 7ms/step - loss: 0.0012 - accuracy: 1.0000 - val_loss: 1.4487 - val_accuracy: 0.8167
# Epoch 227/1000
# 17/17 [==============================] - 0s 7ms/step - loss: 0.0011 - accuracy: 1.0000 - val_loss: 1.4516 - val_accuracy: 0.8167
# Epoch 228/1000
# 17/17 [==============================] - 0s 7ms/step - loss: 0.0012 - accuracy: 1.0000 - val_loss: 1.4638 - val_accuracy: 0.8167
# Epoch 229/1000
# 17/17 [==============================] - 0s 7ms/step - loss: 0.0011 - accuracy: 1.0000 - val_loss: 1.4580 - val_accuracy: 0.8000
# Epoch 230/1000
# 17/17 [==============================] - 0s 7ms/step - loss: 0.0011 - accuracy: 1.0000 - val_loss: 1.4703 - val_accuracy: 0.8167
# Epoch 231/1000
# 17/17 [==============================] - 0s 7ms/step - loss: 0.0011 - accuracy: 1.0000 - val_loss: 1.4722 - val_accuracy: 0.8167
# Epoch 232/1000
# 17/17 [==============================] - 0s 7ms/step - loss: 9.7540e-04 - accuracy: 1.0000 - val_loss: 1.4715 - val_accuracy: 0.8167
# Epoch 233/1000
# 17/17 [==============================] - 0s 7ms/step - loss: 9.8913e-04 - accuracy: 1.0000 - val_loss: 1.4854 - val_accuracy: 0.8167
# Epoch 234/1000
# 17/17 [==============================] - 0s 7ms/step - loss: 0.0011 - accuracy: 1.0000 - val_loss: 1.4731 - val_accuracy: 0.8000
# Epoch 235/1000
# 17/17 [==============================] - 0s 7ms/step - loss: 9.5925e-04 - accuracy: 1.0000 - val_loss: 1.4773 - val_accuracy: 0.8167
# Epoch 236/1000
# 17/17 [==============================] - 0s 8ms/step - loss: 9.8790e-04 - accuracy: 1.0000 - val_loss: 1.5002 - val_accuracy: 0.8167
# Epoch 237/1000
# 17/17 [==============================] - 0s 7ms/step - loss: 8.4544e-04 - accuracy: 1.0000 - val_loss: 1.4915 - val_accuracy: 0.8000
# Epoch 238/1000
# 17/17 [==============================] - 0s 7ms/step - loss: 9.0842e-04 - accuracy: 1.0000 - val_loss: 1.4933 - val_accuracy: 0.8167
# Epoch 239/1000
# 17/17 [==============================] - 0s 7ms/step - loss: 8.1490e-04 - accuracy: 1.0000 - val_loss: 1.4951 - val_accuracy: 0.8167
# Epoch 240/1000
# 17/17 [==============================] - 0s 7ms/step - loss: 9.2745e-04 - accuracy: 1.0000 - val_loss: 1.5027 - val_accuracy: 0.8167
# Epoch 241/1000
# 17/17 [==============================] - 0s 7ms/step - loss: 8.2972e-04 - accuracy: 1.0000 - val_loss: 1.5002 - val_accuracy: 0.8000
# Epoch 242/1000
# 17/17 [==============================] - 0s 7ms/step - loss: 8.1125e-04 - accuracy: 1.0000 - val_loss: 1.5126 - val_accuracy: 0.8167
# Epoch 243/1000
# 17/17 [==============================] - 0s 7ms/step - loss: 7.7599e-04 - accuracy: 1.0000 - val_loss: 1.5159 - val_accuracy: 0.8167
# Epoch 244/1000
# 17/17 [==============================] - 0s 7ms/step - loss: 7.4367e-04 - accuracy: 1.0000 - val_loss: 1.5219 - val_accuracy: 0.8167
# Epoch 245/1000
# 17/17 [==============================] - 0s 7ms/step - loss: 7.6002e-04 - accuracy: 1.0000 - val_loss: 1.5215 - val_accuracy: 0.8000
# Epoch 246/1000
# 17/17 [==============================] - 0s 7ms/step - loss: 7.4623e-04 - accuracy: 1.0000 - val_loss: 1.5324 - val_accuracy: 0.8167
# Epoch 247/1000
# 17/17 [==============================] - 0s 7ms/step - loss: 7.1640e-04 - accuracy: 1.0000 - val_loss: 1.5308 - val_accuracy: 0.8000
# Epoch 248/1000
# 17/17 [==============================] - 0s 7ms/step - loss: 7.2429e-04 - accuracy: 1.0000 - val_loss: 1.5306 - val_accuracy: 0.8000
# Epoch 249/1000
# 17/17 [==============================] - 0s 7ms/step - loss: 6.7129e-04 - accuracy: 1.0000 - val_loss: 1.5408 - val_accuracy: 0.8167
# Epoch 250/1000
# 17/17 [==============================] - 0s 7ms/step - loss: 6.8227e-04 - accuracy: 1.0000 - val_loss: 1.5449 - val_accuracy: 0.8167
# Epoch 251/1000
# 17/17 [==============================] - 0s 7ms/step - loss: 6.8590e-04 - accuracy: 1.0000 - val_loss: 1.5447 - val_accuracy: 0.8167
# Epoch 252/1000
# 17/17 [==============================] - 0s 7ms/step - loss: 6.6146e-04 - accuracy: 1.0000 - val_loss: 1.5472 - val_accuracy: 0.8000
# Epoch 253/1000
# 17/17 [==============================] - 0s 7ms/step - loss: 6.6758e-04 - accuracy: 1.0000 - val_loss: 1.5515 - val_accuracy: 0.8167
# Epoch 254/1000
# 17/17 [==============================] - 0s 7ms/step - loss: 6.3174e-04 - accuracy: 1.0000 - val_loss: 1.5580 - val_accuracy: 0.8000
# Epoch 255/1000
# 17/17 [==============================] - 0s 7ms/step - loss: 6.2554e-04 - accuracy: 1.0000 - val_loss: 1.5595 - val_accuracy: 0.8167
# Epoch 256/1000
# 17/17 [==============================] - 0s 7ms/step - loss: 5.9550e-04 - accuracy: 1.0000 - val_loss: 1.5656 - val_accuracy: 0.8167
# Epoch 257/1000
# 17/17 [==============================] - 0s 8ms/step - loss: 5.9041e-04 - accuracy: 1.0000 - val_loss: 1.5659 - val_accuracy: 0.8000
# Epoch 258/1000
# 17/17 [==============================] - 0s 7ms/step - loss: 5.9468e-04 - accuracy: 1.0000 - val_loss: 1.5808 - val_accuracy: 0.8167
# Epoch 259/1000
# 17/17 [==============================] - 0s 7ms/step - loss: 6.6121e-04 - accuracy: 1.0000 - val_loss: 1.5743 - val_accuracy: 0.8000
# Epoch 260/1000
# 17/17 [==============================] - 0s 7ms/step - loss: 5.6800e-04 - accuracy: 1.0000 - val_loss: 1.5783 - val_accuracy: 0.7833
# Epoch 261/1000
# 17/17 [==============================] - 0s 7ms/step - loss: 6.6379e-04 - accuracy: 1.0000 - val_loss: 1.5919 - val_accuracy: 0.8167
# Epoch 262/1000
# 17/17 [==============================] - 0s 8ms/step - loss: 5.5701e-04 - accuracy: 1.0000 - val_loss: 1.5876 - val_accuracy: 0.8000
# Epoch 263/1000
# 17/17 [==============================] - 0s 8ms/step - loss: 5.2620e-04 - accuracy: 1.0000 - val_loss: 1.5900 - val_accuracy: 0.8167
# Epoch 264/1000
# 17/17 [==============================] - 0s 7ms/step - loss: 5.2790e-04 - accuracy: 1.0000 - val_loss: 1.5891 - val_accuracy: 0.7833
# Epoch 265/1000
# 17/17 [==============================] - 0s 7ms/step - loss: 5.3425e-04 - accuracy: 1.0000 - val_loss: 1.6000 - val_accuracy: 0.8167
# Epoch 266/1000
# 17/17 [==============================] - 0s 8ms/step - loss: 5.1023e-04 - accuracy: 1.0000 - val_loss: 1.5980 - val_accuracy: 0.8000
# Epoch 267/1000
# 17/17 [==============================] - 0s 8ms/step - loss: 4.7589e-04 - accuracy: 1.0000 - val_loss: 1.6055 - val_accuracy: 0.8167
# Epoch 268/1000
# 17/17 [==============================] - 0s 8ms/step - loss: 4.8765e-04 - accuracy: 1.0000 - val_loss: 1.6037 - val_accuracy: 0.8167
# Epoch 269/1000
# 17/17 [==============================] - 0s 8ms/step - loss: 4.7040e-04 - accuracy: 1.0000 - val_loss: 1.6064 - val_accuracy: 0.8000
# Epoch 270/1000
# 17/17 [==============================] - 0s 7ms/step - loss: 4.6271e-04 - accuracy: 1.0000 - val_loss: 1.6127 - val_accuracy: 0.8167
# Epoch 271/1000
# 17/17 [==============================] - 0s 7ms/step - loss: 4.7381e-04 - accuracy: 1.0000 - val_loss: 1.6109 - val_accuracy: 0.7833
# Epoch 272/1000
# 17/17 [==============================] - 0s 8ms/step - loss: 4.5041e-04 - accuracy: 1.0000 - val_loss: 1.6219 - val_accuracy: 0.8167
# Epoch 273/1000
# 17/17 [==============================] - 0s 8ms/step - loss: 4.7087e-04 - accuracy: 1.0000 - val_loss: 1.6274 - val_accuracy: 0.8167
# Epoch 274/1000
# 17/17 [==============================] - 0s 8ms/step - loss: 4.4448e-04 - accuracy: 1.0000 - val_loss: 1.6246 - val_accuracy: 0.8167
# Epoch 275/1000
# 17/17 [==============================] - 0s 8ms/step - loss: 4.3345e-04 - accuracy: 1.0000 - val_loss: 1.6285 - val_accuracy: 0.8167
# Epoch 276/1000
# 17/17 [==============================] - 0s 7ms/step - loss: 4.3502e-04 - accuracy: 1.0000 - val_loss: 1.6331 - val_accuracy: 0.7833
# Epoch 277/1000
# 17/17 [==============================] - 0s 7ms/step - loss: 4.0734e-04 - accuracy: 1.0000 - val_loss: 1.6395 - val_accuracy: 0.8167
# Epoch 278/1000
# 17/17 [==============================] - 0s 7ms/step - loss: 4.0451e-04 - accuracy: 1.0000 - val_loss: 1.6365 - val_accuracy: 0.7833
# Epoch 279/1000
# 17/17 [==============================] - 0s 7ms/step - loss: 4.0722e-04 - accuracy: 1.0000 - val_loss: 1.6408 - val_accuracy: 0.7833
# Epoch 280/1000
# 17/17 [==============================] - 0s 7ms/step - loss: 4.1145e-04 - accuracy: 1.0000 - val_loss: 1.6440 - val_accuracy: 0.8000
# Epoch 281/1000
# 17/17 [==============================] - 0s 7ms/step - loss: 4.1202e-04 - accuracy: 1.0000 - val_loss: 1.6491 - val_accuracy: 0.8167
# Epoch 282/1000
# 17/17 [==============================] - 0s 7ms/step - loss: 3.9320e-04 - accuracy: 1.0000 - val_loss: 1.6507 - val_accuracy: 0.7833
# Epoch 283/1000
# 17/17 [==============================] - 0s 8ms/step - loss: 3.9160e-04 - accuracy: 1.0000 - val_loss: 1.6551 - val_accuracy: 0.7833
# Epoch 284/1000
# 17/17 [==============================] - 0s 8ms/step - loss: 3.8423e-04 - accuracy: 1.0000 - val_loss: 1.6645 - val_accuracy: 0.8167
# Epoch 285/1000
# 17/17 [==============================] - 0s 7ms/step - loss: 3.7312e-04 - accuracy: 1.0000 - val_loss: 1.6606 - val_accuracy: 0.8167
# Epoch 286/1000
# 17/17 [==============================] - 0s 8ms/step - loss: 3.5833e-04 - accuracy: 1.0000 - val_loss: 1.6569 - val_accuracy: 0.7833
# Epoch 287/1000
# 17/17 [==============================] - 0s 8ms/step - loss: 3.4512e-04 - accuracy: 1.0000 - val_loss: 1.6715 - val_accuracy: 0.8167
# Epoch 288/1000
# 17/17 [==============================] - 0s 8ms/step - loss: 3.5426e-04 - accuracy: 1.0000 - val_loss: 1.6653 - val_accuracy: 0.7833
# Epoch 289/1000
# 17/17 [==============================] - 0s 7ms/step - loss: 3.4124e-04 - accuracy: 1.0000 - val_loss: 1.6810 - val_accuracy: 0.8167
# Epoch 290/1000
# 17/17 [==============================] - 0s 8ms/step - loss: 3.3425e-04 - accuracy: 1.0000 - val_loss: 1.6759 - val_accuracy: 0.7833
# Epoch 291/1000
# 17/17 [==============================] - 0s 7ms/step - loss: 3.3038e-04 - accuracy: 1.0000 - val_loss: 1.6847 - val_accuracy: 0.8000
# Epoch 292/1000
# 17/17 [==============================] - 0s 7ms/step - loss: 3.3284e-04 - accuracy: 1.0000 - val_loss: 1.6843 - val_accuracy: 0.8167
# Epoch 293/1000
# 17/17 [==============================] - 0s 7ms/step - loss: 3.1639e-04 - accuracy: 1.0000 - val_loss: 1.6859 - val_accuracy: 0.7833
# Epoch 294/1000
# 17/17 [==============================] - 0s 7ms/step - loss: 3.1244e-04 - accuracy: 1.0000 - val_loss: 1.6906 - val_accuracy: 0.8167
# Epoch 295/1000
# 17/17 [==============================] - 0s 7ms/step - loss: 3.1021e-04 - accuracy: 1.0000 - val_loss: 1.6862 - val_accuracy: 0.7833
# Epoch 296/1000
# 17/17 [==============================] - 0s 8ms/step - loss: 3.3233e-04 - accuracy: 1.0000 - val_loss: 1.7089 - val_accuracy: 0.8167
# Epoch 297/1000
# 17/17 [==============================] - 0s 8ms/step - loss: 3.0084e-04 - accuracy: 1.0000 - val_loss: 1.6946 - val_accuracy: 0.7833
# Epoch 298/1000
# 17/17 [==============================] - 0s 7ms/step - loss: 2.8353e-04 - accuracy: 1.0000 - val_loss: 1.7073 - val_accuracy: 0.8167
# Epoch 299/1000
# 17/17 [==============================] - 0s 7ms/step - loss: 3.6728e-04 - accuracy: 1.0000 - val_loss: 1.7053 - val_accuracy: 0.7833
# Epoch 300/1000
# 17/17 [==============================] - 0s 8ms/step - loss: 3.0835e-04 - accuracy: 1.0000 - val_loss: 1.7129 - val_accuracy: 0.7833
# Epoch 301/1000
# 17/17 [==============================] - 0s 8ms/step - loss: 2.9216e-04 - accuracy: 1.0000 - val_loss: 1.7112 - val_accuracy: 0.7833
# Epoch 302/1000
# 17/17 [==============================] - 0s 7ms/step - loss: 2.8033e-04 - accuracy: 1.0000 - val_loss: 1.7149 - val_accuracy: 0.8167
# Epoch 303/1000
# 17/17 [==============================] - 0s 8ms/step - loss: 2.8249e-04 - accuracy: 1.0000 - val_loss: 1.7241 - val_accuracy: 0.8167
# Epoch 304/1000
# 17/17 [==============================] - 0s 7ms/step - loss: 2.7703e-04 - accuracy: 1.0000 - val_loss: 1.7184 - val_accuracy: 0.7833
# Epoch 305/1000
# 17/17 [==============================] - 0s 7ms/step - loss: 2.6351e-04 - accuracy: 1.0000 - val_loss: 1.7289 - val_accuracy: 0.8167
# Epoch 306/1000
# 17/17 [==============================] - 0s 7ms/step - loss: 2.6866e-04 - accuracy: 1.0000 - val_loss: 1.7234 - val_accuracy: 0.7833
# Epoch 307/1000
# 17/17 [==============================] - 0s 7ms/step - loss: 2.6088e-04 - accuracy: 1.0000 - val_loss: 1.7289 - val_accuracy: 0.7833
# Epoch 308/1000
# 17/17 [==============================] - 0s 7ms/step - loss: 2.6353e-04 - accuracy: 1.0000 - val_loss: 1.7350 - val_accuracy: 0.8000
# Epoch 309/1000
# 17/17 [==============================] - 0s 7ms/step - loss: 2.4735e-04 - accuracy: 1.0000 - val_loss: 1.7348 - val_accuracy: 0.7833
# Epoch 310/1000
# 17/17 [==============================] - 0s 8ms/step - loss: 2.4262e-04 - accuracy: 1.0000 - val_loss: 1.7396 - val_accuracy: 0.8000
# Epoch 311/1000
# 17/17 [==============================] - 0s 8ms/step - loss: 2.4651e-04 - accuracy: 1.0000 - val_loss: 1.7430 - val_accuracy: 0.8167
# Epoch 312/1000
# 17/17 [==============================] - 0s 7ms/step - loss: 2.3623e-04 - accuracy: 1.0000 - val_loss: 1.7423 - val_accuracy: 0.7833
# Epoch 313/1000
# 17/17 [==============================] - 0s 8ms/step - loss: 2.4029e-04 - accuracy: 1.0000 - val_loss: 1.7476 - val_accuracy: 0.7833
# Epoch 314/1000
# 17/17 [==============================] - 0s 8ms/step - loss: 2.3058e-04 - accuracy: 1.0000 - val_loss: 1.7536 - val_accuracy: 0.8167
# Epoch 315/1000
# 17/17 [==============================] - 0s 7ms/step - loss: 2.2904e-04 - accuracy: 1.0000 - val_loss: 1.7490 - val_accuracy: 0.7833
# Epoch 316/1000
# 17/17 [==============================] - 0s 8ms/step - loss: 2.3551e-04 - accuracy: 1.0000 - val_loss: 1.7652 - val_accuracy: 0.8167
# Epoch 317/1000
# 17/17 [==============================] - 0s 7ms/step - loss: 2.3025e-04 - accuracy: 1.0000 - val_loss: 1.7571 - val_accuracy: 0.7833
# Epoch 318/1000
# 17/17 [==============================] - 0s 8ms/step - loss: 2.2207e-04 - accuracy: 1.0000 - val_loss: 1.7607 - val_accuracy: 0.8000
# Epoch 319/1000
# 17/17 [==============================] - 0s 8ms/step - loss: 2.1574e-04 - accuracy: 1.0000 - val_loss: 1.7614 - val_accuracy: 0.7833
# Epoch 320/1000
# ...
# Epoch 894/1000
# 17/17 [==============================] - 0s 9ms/step - loss: 4.4808e-07 - accuracy: 1.0000 - val_loss: 3.0045 - val_accuracy: 0.8000
# Epoch 895/1000
# 17/17 [==============================] - 0s 12ms/step - loss: 4.5210e-07 - accuracy: 1.0000 - val_loss: 3.0000 - val_accuracy: 0.7833
# Epoch 896/1000
# 17/17 [==============================] - 0s 12ms/step - loss: 4.3488e-07 - accuracy: 1.0000 - val_loss: 3.0045 - val_accuracy: 0.7833
# Epoch 897/1000
# 17/17 [==============================] - 0s 11ms/step - loss: 4.3020e-07 - accuracy: 1.0000 - val_loss: 3.0054 - val_accuracy: 0.7833
# Epoch 898/1000
# 17/17 [==============================] - 0s 8ms/step - loss: 4.3410e-07 - accuracy: 1.0000 - val_loss: 3.0074 - val_accuracy: 0.7833
# Epoch 899/1000
# 17/17 [==============================] - 0s 8ms/step - loss: 4.2215e-07 - accuracy: 1.0000 - val_loss: 3.0121 - val_accuracy: 0.7833
# Epoch 900/1000
# 17/17 [==============================] - 0s 8ms/step - loss: 4.1471e-07 - accuracy: 1.0000 - val_loss: 3.0086 - val_accuracy: 0.7833
# Epoch 901/1000
# 17/17 [==============================] - 0s 8ms/step - loss: 4.1964e-07 - accuracy: 1.0000 - val_loss: 3.0125 - val_accuracy: 0.7833
# Epoch 902/1000
# 17/17 [==============================] - 0s 8ms/step - loss: 4.0954e-07 - accuracy: 1.0000 - val_loss: 3.0174 - val_accuracy: 0.7833
# Epoch 903/1000
# 17/17 [==============================] - 0s 8ms/step - loss: 4.0474e-07 - accuracy: 1.0000 - val_loss: 3.0171 - val_accuracy: 0.7833
# Epoch 904/1000
# 17/17 [==============================] - 0s 8ms/step - loss: 4.0069e-07 - accuracy: 1.0000 - val_loss: 3.0198 - val_accuracy: 0.7833
# Epoch 905/1000
# 17/17 [==============================] - 0s 8ms/step - loss: 4.0004e-07 - accuracy: 1.0000 - val_loss: 3.0247 - val_accuracy: 0.7833
# Epoch 906/1000
# 17/17 [==============================] - 0s 8ms/step - loss: 3.9473e-07 - accuracy: 1.0000 - val_loss: 3.0228 - val_accuracy: 0.7833
# Epoch 907/1000
# 17/17 [==============================] - 0s 8ms/step - loss: 3.9394e-07 - accuracy: 1.0000 - val_loss: 3.0251 - val_accuracy: 0.7833
# Epoch 908/1000
# 17/17 [==============================] - 0s 8ms/step - loss: 3.9737e-07 - accuracy: 1.0000 - val_loss: 3.0257 - val_accuracy: 0.7833
# Epoch 909/1000
# 17/17 [==============================] - 0s 8ms/step - loss: 3.8731e-07 - accuracy: 1.0000 - val_loss: 3.0289 - val_accuracy: 0.7833
# Epoch 910/1000
# 17/17 [==============================] - 0s 8ms/step - loss: 3.7766e-07 - accuracy: 1.0000 - val_loss: 3.0306 - val_accuracy: 0.7833
# Epoch 911/1000
# 17/17 [==============================] - 0s 8ms/step - loss: 3.7531e-07 - accuracy: 1.0000 - val_loss: 3.0313 - val_accuracy: 0.7833
# Epoch 912/1000
# 17/17 [==============================] - 0s 8ms/step - loss: 3.7799e-07 - accuracy: 1.0000 - val_loss: 3.0317 - val_accuracy: 0.7833
# Epoch 913/1000
# 17/17 [==============================] - 0s 8ms/step - loss: 3.7129e-07 - accuracy: 1.0000 - val_loss: 3.0361 - val_accuracy: 0.7833
# Epoch 914/1000
# 17/17 [==============================] - 0s 8ms/step - loss: 3.6538e-07 - accuracy: 1.0000 - val_loss: 3.0387 - val_accuracy: 0.7833
# Epoch 915/1000
# 17/17 [==============================] - 0s 8ms/step - loss: 3.5765e-07 - accuracy: 1.0000 - val_loss: 3.0417 - val_accuracy: 0.7833
# Epoch 916/1000
# 17/17 [==============================] - 0s 8ms/step - loss: 3.6064e-07 - accuracy: 1.0000 - val_loss: 3.0406 - val_accuracy: 0.7833
# Epoch 917/1000
# 17/17 [==============================] - 0s 8ms/step - loss: 3.6274e-07 - accuracy: 1.0000 - val_loss: 3.0414 - val_accuracy: 0.7833
# Epoch 918/1000
# 17/17 [==============================] - 0s 8ms/step - loss: 3.6615e-07 - accuracy: 1.0000 - val_loss: 3.0418 - val_accuracy: 0.7833
# Epoch 919/1000
# 17/17 [==============================] - 0s 8ms/step - loss: 3.5778e-07 - accuracy: 1.0000 - val_loss: 3.0480 - val_accuracy: 0.8000
# Epoch 920/1000
# 17/17 [==============================] - 0s 8ms/step - loss: 3.5520e-07 - accuracy: 1.0000 - val_loss: 3.0477 - val_accuracy: 0.7833
# Epoch 921/1000
# 17/17 [==============================] - 0s 8ms/step - loss: 3.3850e-07 - accuracy: 1.0000 - val_loss: 3.0508 - val_accuracy: 0.7833
# Epoch 922/1000
# 17/17 [==============================] - 0s 8ms/step - loss: 3.3865e-07 - accuracy: 1.0000 - val_loss: 3.0503 - val_accuracy: 0.7833
# Epoch 923/1000
# 17/17 [==============================] - 0s 8ms/step - loss: 3.4241e-07 - accuracy: 1.0000 - val_loss: 3.0554 - val_accuracy: 0.7833
# Epoch 924/1000
# 17/17 [==============================] - 0s 8ms/step - loss: 3.3197e-07 - accuracy: 1.0000 - val_loss: 3.0556 - val_accuracy: 0.7833
# Epoch 925/1000
# 17/17 [==============================] - 0s 8ms/step - loss: 3.4025e-07 - accuracy: 1.0000 - val_loss: 3.0589 - val_accuracy: 0.7833
# Epoch 926/1000
# 17/17 [==============================] - 0s 8ms/step - loss: 3.3864e-07 - accuracy: 1.0000 - val_loss: 3.0612 - val_accuracy: 0.8000
# Epoch 927/1000
# 17/17 [==============================] - 0s 8ms/step - loss: 3.3609e-07 - accuracy: 1.0000 - val_loss: 3.0576 - val_accuracy: 0.7833
# Epoch 928/1000
# 17/17 [==============================] - 0s 8ms/step - loss: 3.2056e-07 - accuracy: 1.0000 - val_loss: 3.0666 - val_accuracy: 0.7833
# Epoch 929/1000
# 17/17 [==============================] - 0s 8ms/step - loss: 3.2039e-07 - accuracy: 1.0000 - val_loss: 3.0653 - val_accuracy: 0.7833
# Epoch 930/1000
# 17/17 [==============================] - 0s 8ms/step - loss: 3.1795e-07 - accuracy: 1.0000 - val_loss: 3.0677 - val_accuracy: 0.7833
# Epoch 931/1000
# 17/17 [==============================] - 0s 8ms/step - loss: 3.1424e-07 - accuracy: 1.0000 - val_loss: 3.0700 - val_accuracy: 0.7833
# Epoch 932/1000
# 17/17 [==============================] - 0s 8ms/step - loss: 3.0603e-07 - accuracy: 1.0000 - val_loss: 3.0723 - val_accuracy: 0.7833
# Epoch 933/1000
# 17/17 [==============================] - 0s 8ms/step - loss: 3.0087e-07 - accuracy: 1.0000 - val_loss: 3.0726 - val_accuracy: 0.7833
# Epoch 934/1000
# 17/17 [==============================] - 0s 8ms/step - loss: 3.0287e-07 - accuracy: 1.0000 - val_loss: 3.0738 - val_accuracy: 0.7833
# Epoch 935/1000
# 17/17 [==============================] - 0s 8ms/step - loss: 3.0347e-07 - accuracy: 1.0000 - val_loss: 3.0784 - val_accuracy: 0.7833
# Epoch 936/1000
# 17/17 [==============================] - 0s 8ms/step - loss: 2.9911e-07 - accuracy: 1.0000 - val_loss: 3.0795 - val_accuracy: 0.7833
# Epoch 937/1000
# 17/17 [==============================] - 0s 8ms/step - loss: 2.9175e-07 - accuracy: 1.0000 - val_loss: 3.0817 - val_accuracy: 0.7833
# Epoch 938/1000
# 17/17 [==============================] - 0s 8ms/step - loss: 2.8959e-07 - accuracy: 1.0000 - val_loss: 3.0816 - val_accuracy: 0.7833
# Epoch 939/1000
# 17/17 [==============================] - 0s 8ms/step - loss: 2.8518e-07 - accuracy: 1.0000 - val_loss: 3.0861 - val_accuracy: 0.7833
# Epoch 940/1000
# 17/17 [==============================] - 0s 8ms/step - loss: 2.8190e-07 - accuracy: 1.0000 - val_loss: 3.0856 - val_accuracy: 0.7833
# Epoch 941/1000
# 17/17 [==============================] - 0s 8ms/step - loss: 2.8020e-07 - accuracy: 1.0000 - val_loss: 3.0895 - val_accuracy: 0.8000
# Epoch 942/1000
# 17/17 [==============================] - 0s 8ms/step - loss: 2.8809e-07 - accuracy: 1.0000 - val_loss: 3.0901 - val_accuracy: 0.7833
# Epoch 943/1000
# 17/17 [==============================] - 0s 8ms/step - loss: 2.7357e-07 - accuracy: 1.0000 - val_loss: 3.0944 - val_accuracy: 0.7833
# Epoch 944/1000
# 17/17 [==============================] - 0s 8ms/step - loss: 2.7227e-07 - accuracy: 1.0000 - val_loss: 3.0964 - val_accuracy: 0.7833
# Epoch 945/1000
# 17/17 [==============================] - 0s 8ms/step - loss: 2.7231e-07 - accuracy: 1.0000 - val_loss: 3.0948 - val_accuracy: 0.7833
# Epoch 946/1000
# 17/17 [==============================] - 0s 8ms/step - loss: 2.7182e-07 - accuracy: 1.0000 - val_loss: 3.0976 - val_accuracy: 0.7833
# Epoch 947/1000
# 17/17 [==============================] - 0s 8ms/step - loss: 2.6289e-07 - accuracy: 1.0000 - val_loss: 3.0994 - val_accuracy: 0.7833
# Epoch 948/1000
# 17/17 [==============================] - 0s 8ms/step - loss: 2.6102e-07 - accuracy: 1.0000 - val_loss: 3.1027 - val_accuracy: 0.7833
# Epoch 949/1000
# 17/17 [==============================] - 0s 8ms/step - loss: 2.6226e-07 - accuracy: 1.0000 - val_loss: 3.1051 - val_accuracy: 0.7833
# Epoch 950/1000
# 17/17 [==============================] - 0s 8ms/step - loss: 2.5836e-07 - accuracy: 1.0000 - val_loss: 3.1085 - val_accuracy: 0.8000
# Epoch 951/1000
# 17/17 [==============================] - 0s 8ms/step - loss: 2.6181e-07 - accuracy: 1.0000 - val_loss: 3.1075 - val_accuracy: 0.7833
# Epoch 952/1000
# 17/17 [==============================] - 0s 8ms/step - loss: 2.5182e-07 - accuracy: 1.0000 - val_loss: 3.1100 - val_accuracy: 0.7833
# Epoch 953/1000
# 17/17 [==============================] - 0s 8ms/step - loss: 2.7274e-07 - accuracy: 1.0000 - val_loss: 3.1095 - val_accuracy: 0.7833
# Epoch 954/1000
# 17/17 [==============================] - 0s 8ms/step - loss: 2.5056e-07 - accuracy: 1.0000 - val_loss: 3.1103 - val_accuracy: 0.7833
# Epoch 955/1000
# 17/17 [==============================] - 0s 8ms/step - loss: 2.4411e-07 - accuracy: 1.0000 - val_loss: 3.1130 - val_accuracy: 0.7833
# Epoch 956/1000
# 17/17 [==============================] - 0s 8ms/step - loss: 2.4317e-07 - accuracy: 1.0000 - val_loss: 3.1151 - val_accuracy: 0.7833
# Epoch 957/1000
# 17/17 [==============================] - 0s 8ms/step - loss: 2.4124e-07 - accuracy: 1.0000 - val_loss: 3.1181 - val_accuracy: 0.7833
# Epoch 958/1000
# 17/17 [==============================] - 0s 8ms/step - loss: 2.4127e-07 - accuracy: 1.0000 - val_loss: 3.1203 - val_accuracy: 0.7833
# Epoch 959/1000
# 17/17 [==============================] - 0s 8ms/step - loss: 2.3819e-07 - accuracy: 1.0000 - val_loss: 3.1228 - val_accuracy: 0.7833
# Epoch 960/1000
# 17/17 [==============================] - 0s 9ms/step - loss: 2.3739e-07 - accuracy: 1.0000 - val_loss: 3.1282 - val_accuracy: 0.7833
# Epoch 961/1000
# 17/17 [==============================] - 0s 9ms/step - loss: 2.3988e-07 - accuracy: 1.0000 - val_loss: 3.1260 - val_accuracy: 0.8000
# Epoch 962/1000
# 17/17 [==============================] - 0s 9ms/step - loss: 2.4446e-07 - accuracy: 1.0000 - val_loss: 3.1251 - val_accuracy: 0.7833
# Epoch 963/1000
# 17/17 [==============================] - 0s 9ms/step - loss: 2.2462e-07 - accuracy: 1.0000 - val_loss: 3.1297 - val_accuracy: 0.7833
# Epoch 964/1000
# 17/17 [==============================] - 0s 9ms/step - loss: 2.2564e-07 - accuracy: 1.0000 - val_loss: 3.1342 - val_accuracy: 0.7833
# Epoch 965/1000
# 17/17 [==============================] - 0s 9ms/step - loss: 2.2261e-07 - accuracy: 1.0000 - val_loss: 3.1329 - val_accuracy: 0.7833
# Epoch 966/1000
# 17/17 [==============================] - 0s 9ms/step - loss: 2.2101e-07 - accuracy: 1.0000 - val_loss: 3.1366 - val_accuracy: 0.7833
# Epoch 967/1000
# 17/17 [==============================] - 0s 9ms/step - loss: 2.1603e-07 - accuracy: 1.0000 - val_loss: 3.1364 - val_accuracy: 0.7833
# Epoch 968/1000
# 17/17 [==============================] - 0s 9ms/step - loss: 2.2301e-07 - accuracy: 1.0000 - val_loss: 3.1418 - val_accuracy: 0.8000
# Epoch 969/1000
# 17/17 [==============================] - 0s 8ms/step - loss: 2.2442e-07 - accuracy: 1.0000 - val_loss: 3.1403 - val_accuracy: 0.7833
# Epoch 970/1000
# 17/17 [==============================] - 0s 8ms/step - loss: 2.1015e-07 - accuracy: 1.0000 - val_loss: 3.1431 - val_accuracy: 0.7833
# Epoch 971/1000
# 17/17 [==============================] - 0s 9ms/step - loss: 2.1322e-07 - accuracy: 1.0000 - val_loss: 3.1415 - val_accuracy: 0.7833
# Epoch 972/1000
# 17/17 [==============================] - 0s 9ms/step - loss: 2.0641e-07 - accuracy: 1.0000 - val_loss: 3.1466 - val_accuracy: 0.7833
# Epoch 973/1000
# 17/17 [==============================] - 0s 9ms/step - loss: 2.0685e-07 - accuracy: 1.0000 - val_loss: 3.1471 - val_accuracy: 0.7833
# Epoch 974/1000
# 17/17 [==============================] - 0s 9ms/step - loss: 2.0276e-07 - accuracy: 1.0000 - val_loss: 3.1491 - val_accuracy: 0.7833
# Epoch 975/1000
# 17/17 [==============================] - 0s 9ms/step - loss: 2.0089e-07 - accuracy: 1.0000 - val_loss: 3.1524 - val_accuracy: 0.7833
# Epoch 976/1000
# 17/17 [==============================] - 0s 9ms/step - loss: 2.0617e-07 - accuracy: 1.0000 - val_loss: 3.1542 - val_accuracy: 0.7833
# Epoch 977/1000
# 17/17 [==============================] - 0s 8ms/step - loss: 2.0082e-07 - accuracy: 1.0000 - val_loss: 3.1557 - val_accuracy: 0.7833
# Epoch 978/1000
# 17/17 [==============================] - 0s 8ms/step - loss: 1.9963e-07 - accuracy: 1.0000 - val_loss: 3.1567 - val_accuracy: 0.7833
# Epoch 979/1000
# 17/17 [==============================] - 0s 8ms/step - loss: 1.9329e-07 - accuracy: 1.0000 - val_loss: 3.1603 - val_accuracy: 0.7833
# Epoch 980/1000
# 17/17 [==============================] - 0s 8ms/step - loss: 1.9282e-07 - accuracy: 1.0000 - val_loss: 3.1619 - val_accuracy: 0.7833
# Epoch 981/1000
# 17/17 [==============================] - 0s 8ms/step - loss: 1.9301e-07 - accuracy: 1.0000 - val_loss: 3.1627 - val_accuracy: 0.7833
# Epoch 982/1000
# 17/17 [==============================] - 0s 8ms/step - loss: 1.8604e-07 - accuracy: 1.0000 - val_loss: 3.1665 - val_accuracy: 0.7833
# Epoch 983/1000
# 17/17 [==============================] - 0s 8ms/step - loss: 1.8463e-07 - accuracy: 1.0000 - val_loss: 3.1663 - val_accuracy: 0.7833
# Epoch 984/1000
# 17/17 [==============================] - 0s 8ms/step - loss: 1.8836e-07 - accuracy: 1.0000 - val_loss: 3.1705 - val_accuracy: 0.7833
# Epoch 985/1000
# 17/17 [==============================] - 0s 8ms/step - loss: 1.8519e-07 - accuracy: 1.0000 - val_loss: 3.1722 - val_accuracy: 0.7833
# Epoch 986/1000
# 17/17 [==============================] - 0s 8ms/step - loss: 1.8184e-07 - accuracy: 1.0000 - val_loss: 3.1730 - val_accuracy: 0.7833
# Epoch 987/1000
# 17/17 [==============================] - 0s 8ms/step - loss: 1.7946e-07 - accuracy: 1.0000 - val_loss: 3.1767 - val_accuracy: 0.7833
# Epoch 988/1000
# 17/17 [==============================] - 0s 8ms/step - loss: 1.7732e-07 - accuracy: 1.0000 - val_loss: 3.1753 - val_accuracy: 0.7833
# Epoch 989/1000
# 17/17 [==============================] - 0s 8ms/step - loss: 1.7858e-07 - accuracy: 1.0000 - val_loss: 3.1786 - val_accuracy: 0.7833
# Epoch 990/1000
# 17/17 [==============================] - 0s 8ms/step - loss: 1.7555e-07 - accuracy: 1.0000 - val_loss: 3.1803 - val_accuracy: 0.7833
# Epoch 991/1000
# 17/17 [==============================] - 0s 8ms/step - loss: 1.7202e-07 - accuracy: 1.0000 - val_loss: 3.1817 - val_accuracy: 0.7833
# Epoch 992/1000
# 17/17 [==============================] - 0s 8ms/step - loss: 1.7048e-07 - accuracy: 1.0000 - val_loss: 3.1830 - val_accuracy: 0.7833
# Epoch 993/1000
# 17/17 [==============================] - 0s 8ms/step - loss: 1.7293e-07 - accuracy: 1.0000 - val_loss: 3.1854 - val_accuracy: 0.7833
# Epoch 994/1000
# 17/17 [==============================] - 0s 8ms/step - loss: 1.6887e-07 - accuracy: 1.0000 - val_loss: 3.1874 - val_accuracy: 0.7833
# Epoch 995/1000
# 17/17 [==============================] - 0s 8ms/step - loss: 1.6572e-07 - accuracy: 1.0000 - val_loss: 3.1901 - val_accuracy: 0.7833
# Epoch 996/1000
# 17/17 [==============================] - 0s 8ms/step - loss: 1.6424e-07 - accuracy: 1.0000 - val_loss: 3.1928 - val_accuracy: 0.7833
# Epoch 997/1000
# 17/17 [==============================] - 0s 8ms/step - loss: 1.6389e-07 - accuracy: 1.0000 - val_loss: 3.1929 - val_accuracy: 0.7833
# Epoch 998/1000
# 17/17 [==============================] - 0s 8ms/step - loss: 1.6095e-07 - accuracy: 1.0000 - val_loss: 3.1934 - val_accuracy: 0.7833
# Epoch 999/1000
# 17/17 [==============================] - 0s 8ms/step - loss: 1.6029e-07 - accuracy: 1.0000 - val_loss: 3.1968 - val_accuracy: 0.7833
# Epoch 1000/1000
# 17/17 [==============================] - 0s 8ms/step - loss: 1.5683e-07 - accuracy: 1.0000 - val_loss: 3.1977 - val_accuracy: 0.7833
# 0.8333333134651184
# 2/2 [==============================] - 0s 5ms/step - loss: 3.1977 - accuracy: 0.7833
# [3.1976821422576904, 0.7833333611488342]

# %%
pred_test = model.predict(X_test)
pred_test = np.argmax(pred_test, axis = 1)
output["advanced_pred_test"] = pred_test
# Out:
# 2/2 [==============================] - 0s 5ms/step

# %% [markdown]
# # 9. Comparison Experiment
# Under 45 epochs, using identical linear layering between all three and identical convolutional layering for the two CNN models, we can compare the run time and the result of the models.

# %%
PATH = "Training_data"  #path to your training image
file_dir = os.listdir(PATH) #read the images from the directory
file_dir.sort() #Make sure the images are loaded in order
X_train = np.array([])

# Prepare X_train
# The shape of X_train will be (number of examples, height of image, width of image, channel of image)
# GRADED CODE: Binary classification (Data preprocessing)
# hint: use imread(PATH, IMREAD_GRAYSCALE) to load image
### START CODE HERE ### (≈ 9 line)
X_train = np.array([imread(PATH + "/" + i, IMREAD_GRAYSCALE) for i in file_dir])[: , : , : , np.newaxis] / 255
### END CODE HERE ###

# %%
data = read_csv("Training_label.csv")

y_train = []
# Prepare y_train
# The shape of y_train will be (number of examples, 1), we will transpose y_train latter.
# GRADED CODE: Binary classification (Data preprocessing)
### START CODE HERE ### (≈ 2 line)
y_train = np.array(data['label'])[: , np.newaxis]
### END CODE HERE ###

# %%
PATH = "Testing_data"  #path to your testing image
file_dir = os.listdir(PATH)
file_dir.sort()
X_test = np.array([])

# Prepare X_testi
# The shape of X_teset will be (number of examples, height of image, width of image, channel of image)
# GRADED CODE: Binary classification (Data preprocessing)
### START CODE HERE ### (≈ 9 line)
X_test = np.array([imread(PATH + "/" + i, IMREAD_GRAYSCALE) for i in file_dir])[: , : , : , np.newaxis] / 255
### END CODE HERE ###

# %%
X_train, X_val, y_train, y_val = train_test_split(X_train, y_train, test_size=0.1)

y_train = y_train.T #transpose y_train
y_val = y_val.T

# %%
# GRADED CODE: Binary classification
### START CODE HERE ###
learning_rate = 0.001
num_iterations = 20
batch_size = 16
print_cost = True
classes = 2
costs = []   # keep track of cost
accs = []

# build the model
model=Model()
model.add(Flatten())
model.add(Dense(1024, 32))
model.add(Activation("relu"))
model.add(Dense(32, 1))
model.add(Activation("sigmoid"))

# Loop (gradient descent)
for i in range(0, num_iterations):
    if i == 15:
        learning_rate = 3e-5
    print("epoch: ",i)
    mini_batches = random_mini_batches(X_train, y_train, batch_size)
    for batch in mini_batches:
        x_batch, y_batch = batch

        # forward
        AL = model.forward(x_batch)

        # compute cost
        if classes == 2:
            cost = compute_BCE_cost(AL, np.transpose(y_batch))
        else:
            cost = compute_CCE_cost(AL, np.transpose(y_batch))

        # backward
        dA_prev = model.backward(AL = AL, Y = y_batch)

        # update
        model.update(learning_rate)
    acc = np.sum(predict(X_val, None, model, 2) == y_val) / y_val.shape[1]
    print ("Cost after iteration %i: %f" %(i, cost))
    costs.append(cost)
    print("Accuracy after iteration %i: %f" %(i, acc))
    accs.append(acc)
### END CODE HERE ###
            
# plot the cost
plt.plot(np.squeeze(costs))
plt.ylabel('cost')
plt.xlabel('iterations')
plt.title("Learning rate =" + str(learning_rate))
plt.show()

plt.plot(np.squeeze(accs))
plt.ylabel('accuracy')
plt.xlabel('iterations')
plt.title("Learning rate =" + str(learning_rate))
plt.show()
# Out:
# epoch:  0
# Cost after iteration 0: 0.733855
# Accuracy after iteration 0: 0.566667
# epoch:  1
# Cost after iteration 1: 0.707034
# Accuracy after iteration 1: 0.566667
# epoch:  2
# Cost after iteration 2: 0.714613
# Accuracy after iteration 2: 0.566667
# epoch:  3
# Cost after iteration 3: 0.706557
# Accuracy after iteration 3: 0.566667
# epoch:  4
# Cost after iteration 4: 0.640790
# Accuracy after iteration 4: 0.566667
# epoch:  5
# Cost after iteration 5: 0.703915
# Accuracy after iteration 5: 0.566667
# epoch:  6
# Cost after iteration 6: 0.698213
# Accuracy after iteration 6: 0.566667
# epoch:  7
# Cost after iteration 7: 0.711327
# Accuracy after iteration 7: 0.566667
# epoch:  8
# Cost after iteration 8: 0.696425
# Accuracy after iteration 8: 0.566667
# epoch:  9
# Cost after iteration 9: 0.743642
# Accuracy after iteration 9: 0.566667
# epoch:  10
# Cost after iteration 10: 0.639436
# Accuracy after iteration 10: 0.566667
# epoch:  11
# Cost after iteration 11: 0.712915
# Accuracy after iteration 11: 0.566667
# epoch:  12
# Cost after iteration 12: 0.726985
# Accuracy after iteration 12: 0.566667
# epoch:  13
# Cost after iteration 13: 0.722681
# Accuracy after iteration 13: 0.566667
# epoch:  14
# Cost after iteration 14: 0.750541
# Accuracy after iteration 14: 0.566667
# epoch:  15
# Cost after iteration 15: 0.777627
# Accuracy after iteration 15: 0.566667
# epoch:  16
# Cost after iteration 16: 0.694447
# Accuracy after iteration 16: 0.566667
# epoch:  17
# Cost after iteration 17: 0.630804
# Accuracy after iteration 17: 0.566667
# epoch:  18
# Cost after iteration 18: 0.678712
# Accuracy after iteration 18: 0.566667
# epoch:  19
# Cost after iteration 19: 0.749950
# Accuracy after iteration 19: 0.566667

# %%
# GRADED CODE: Binary classification
### START CODE HERE ###
learning_rate = 0.001
num_iterations = 20
batch_size = 16
print_cost = True
classes = 2
costs = []   # keep track of cost
accs = []

# build the model
model=Model()
model.add(Conv(filter_size=3, input_channel=1, output_channel=16, pad=0, stride=2))
model.add(Activation("relu"))
model.add(MaxPool(filter_size=2, stride=2))
model.add(Conv(filter_size=3, input_channel=16, output_channel=16, pad=0, stride=2))
model.add(Activation("relu"))

model.add(Flatten())
model.add(Dense(144, 32))
model.add(Activation("relu"))
model.add(Dense(32, 1))
model.add(Activation("sigmoid"))

# Loop (gradient descent)
for i in range(0, num_iterations):
    if i == 15:
        learning_rate = 3e-5
    print("epoch: ",i)
    mini_batches = random_mini_batches(X_train, y_train, batch_size)
    for batch in mini_batches:
        x_batch, y_batch = batch

        # forward
        AL = model.forward(x_batch)

        # compute cost
        if classes == 2:
            cost = compute_BCE_cost(AL, np.transpose(y_batch))
        else:
            cost = compute_CCE_cost(AL, np.transpose(y_batch))

        # backward
        dA_prev = model.backward(AL = AL, Y = y_batch)

        # update
        model.update(learning_rate)
    acc = np.sum(predict(X_val, None, model, 2) == y_val) / y_val.shape[1]
    print ("Cost after iteration %i: %f" %(i, cost))
    costs.append(cost)
    print("Accuracy after iteration %i: %f" %(i, acc))
    accs.append(acc)
### END CODE HERE ###
            
# plot the cost
plt.plot(np.squeeze(costs))
plt.ylabel('cost')
plt.xlabel('iterations')
plt.title("Learning rate =" + str(learning_rate))
plt.show()

plt.plot(np.squeeze(accs))
plt.ylabel('accuracy')
plt.xlabel('iterations')
plt.title("Learning rate =" + str(learning_rate))
plt.show()
# Out:
# epoch:  0
# Cost after iteration 0: 0.812475
# Accuracy after iteration 0: 0.550000
# epoch:  1
# Cost after iteration 1: 0.723847
# Accuracy after iteration 1: 0.416667
# epoch:  2
# Cost after iteration 2: 0.697566
# Accuracy after iteration 2: 0.383333
# epoch:  3
# Cost after iteration 3: 0.757282
# Accuracy after iteration 3: 0.416667
# epoch:  4
# Cost after iteration 4: 0.689635
# Accuracy after iteration 4: 0.433333
# epoch:  5
# Cost after iteration 5: 0.705859
# Accuracy after iteration 5: 0.466667
# epoch:  6
# Cost after iteration 6: 0.689835
# Accuracy after iteration 6: 0.416667
# epoch:  7
# Cost after iteration 7: 0.704512
# Accuracy after iteration 7: 0.450000
# epoch:  8
# Cost after iteration 8: 0.703413
# Accuracy after iteration 8: 0.433333
# epoch:  9
# Cost after iteration 9: 0.688373
# Accuracy after iteration 9: 0.433333
# epoch:  10
# Cost after iteration 10: 0.684779
# Accuracy after iteration 10: 0.416667
# epoch:  11
# Cost after iteration 11: 0.702188
# Accuracy after iteration 11: 0.450000
# epoch:  12
# Cost after iteration 12: 0.698504
# Accuracy after iteration 12: 0.433333
# epoch:  13
# Cost after iteration 13: 0.695939
# Accuracy after iteration 13: 0.483333
# epoch:  14
# Cost after iteration 14: 0.697126
# Accuracy after iteration 14: 0.433333
# epoch:  15
# Cost after iteration 15: 0.694532
# Accuracy after iteration 15: 0.450000
# epoch:  16
# Cost after iteration 16: 0.688439
# Accuracy after iteration 16: 0.450000
# epoch:  17
# Cost after iteration 17: 0.696938
# Accuracy after iteration 17: 0.450000
# epoch:  18
# Cost after iteration 18: 0.703007
# Accuracy after iteration 18: 0.450000
# epoch:  19
# Cost after iteration 19: 0.691302
# Accuracy after iteration 19: 0.450000

# %%
if y_train.shape[0] == 1:
    y_train = np.transpose(y_train)
    if validation:
        y_val = np.transpose(y_val)
print(y_train.shape)
print(y_val.shape)
# Out:
# (540, 1)
# (60, 1)

# %%
# GRADED CODE: Advanced implementation
### Start training ###
model = tf.keras.models.Sequential([
    tf.keras.layers.Conv2D(16, (3, 3), 2, activation = 'relu', input_shape = (32, 32, 1)),
    tf.keras.layers.MaxPooling2D(2,2),
    tf.keras.layers.Conv2D(16, (3, 3), 2, activation='relu'),
    tf.keras.layers.Flatten(),
    tf.keras.layers.Dense(32, activation='relu'),
    tf.keras.layers.Dense(1, activation='sigmoid') 
])

model.compile(optimizer = 'adam', loss='binary_crossentropy', metrics = ['accuracy'])
model.summary()
history = model.fit(X_train, y_train, epochs = 20, validation_data = (X_val, y_val))

plt.plot(np.squeeze(history.history['loss']))
plt.ylabel('cost')
plt.xlabel('iterations')
plt.show()

plt.plot(np.squeeze(history.history['val_accuracy']))
plt.ylabel('accuracy')
plt.xlabel('iterations')
plt.show()

model.evaluate(X_val, y_val)
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_2 (Conv2D)           (None, 15, 15, 16)        160
#
#  max_pooling2d_2 (MaxPooling  (None, 7, 7, 16)         0
#  2D)
#
#  conv2d_3 (Conv2D)           (None, 3, 3, 16)          2320
#
#  flatten_1 (Flatten)         (None, 144)               0
#
#  dense_4 (Dense)             (None, 32)                4640
#
#  dense_5 (Dense)             (None, 1)                 33
#
# =================================================================
# Total params: 7,153
# Trainable params: 7,153
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/20
# 17/17 [==============================] - 1s 14ms/step - loss: 0.6922 - accuracy: 0.5296 - val_loss: 0.7007 - val_accuracy: 0.4333
# Epoch 2/20
# 17/17 [==============================] - 0s 5ms/step - loss: 0.6809 - accuracy: 0.5741 - val_loss: 0.6730 - val_accuracy: 0.7167
# Epoch 3/20
# 17/17 [==============================] - 0s 5ms/step - loss: 0.6640 - accuracy: 0.7407 - val_loss: 0.6721 - val_accuracy: 0.5833
# Epoch 4/20
# 17/17 [==============================] - 0s 6ms/step - loss: 0.6412 - accuracy: 0.7500 - val_loss: 0.6377 - val_accuracy: 0.7000
# Epoch 5/20
# 17/17 [==============================] - 0s 5ms/step - loss: 0.6070 - accuracy: 0.7815 - val_loss: 0.6216 - val_accuracy: 0.6667
# Epoch 6/20
# 17/17 [==============================] - 0s 6ms/step - loss: 0.5695 - accuracy: 0.7870 - val_loss: 0.5727 - val_accuracy: 0.7333
# Epoch 7/20
# 17/17 [==============================] - 0s 6ms/step - loss: 0.5310 - accuracy: 0.7759 - val_loss: 0.5566 - val_accuracy: 0.7167
# Epoch 8/20
# 17/17 [==============================] - 0s 5ms/step - loss: 0.5132 - accuracy: 0.7759 - val_loss: 0.5760 - val_accuracy: 0.7333
# Epoch 9/20
# 17/17 [==============================] - 0s 6ms/step - loss: 0.5048 - accuracy: 0.7759 - val_loss: 0.5991 - val_accuracy: 0.7000
# Epoch 10/20
# 17/17 [==============================] - 0s 5ms/step - loss: 0.4884 - accuracy: 0.7889 - val_loss: 0.5706 - val_accuracy: 0.7333
# Epoch 11/20
# 17/17 [==============================] - 0s 5ms/step - loss: 0.4935 - accuracy: 0.7704 - val_loss: 0.5824 - val_accuracy: 0.7167
# Epoch 12/20
# 17/17 [==============================] - 0s 6ms/step - loss: 0.4803 - accuracy: 0.7889 - val_loss: 0.5268 - val_accuracy: 0.7500
# Epoch 13/20
# 17/17 [==============================] - 0s 5ms/step - loss: 0.4738 - accuracy: 0.7889 - val_loss: 0.5687 - val_accuracy: 0.7500
# Epoch 14/20
# 17/17 [==============================] - 0s 6ms/step - loss: 0.4726 - accuracy: 0.7963 - val_loss: 0.5384 - val_accuracy: 0.7333
# Epoch 15/20
# 17/17 [==============================] - 0s 6ms/step - loss: 0.4665 - accuracy: 0.7926 - val_loss: 0.5364 - val_accuracy: 0.7667
# Epoch 16/20
# 17/17 [==============================] - 0s 6ms/step - loss: 0.4805 - accuracy: 0.7926 - val_loss: 0.5174 - val_accuracy: 0.7500
# Epoch 17/20
# 17/17 [==============================] - 0s 6ms/step - loss: 0.4870 - accuracy: 0.7648 - val_loss: 0.5668 - val_accuracy: 0.7500
# Epoch 18/20
# 17/17 [==============================] - 0s 6ms/step - loss: 0.4900 - accuracy: 0.7815 - val_loss: 0.5520 - val_accuracy: 0.7500
# Epoch 19/20
# 17/17 [==============================] - 0s 6ms/step - loss: 0.4682 - accuracy: 0.7907 - val_loss: 0.5109 - val_accuracy: 0.7833
# Epoch 20/20
# 17/17 [==============================] - 0s 6ms/step - loss: 0.4757 - accuracy: 0.7981 - val_loss: 0.5234 - val_accuracy: 0.7333
# 2/2 [==============================] - 0s 5ms/step - loss: 0.5234 - accuracy: 0.7333
# [0.5233786106109619, 0.7333333492279053]

# %% [markdown]
# # Submit prediction

# %%
# sanity check
assert(list(output.keys()) == ['conv_initialization', 'zero_padding', 'conv_single_step', 'conv_forward_1', 'conv_forward_2', 'conv_forward_3', 'conv_update_1', 'conv_update_2', 'maxpool_forward', 'flatten_forward', 'flatten_backward', 'model_1', 'model_2', 'model_3', 'model_4', 'basic_pred_test', 'basic_model_layers', 'basic_model_parameters', 'advanced_pred_test'])

# %%
np.save("hw4_output.npy", output)

# %%
# sanity check
submit = np.load("hw4_output.npy", allow_pickle=True).item()
for key, value in submit.items():
    print(str(key) + "： " + str(type(value)))
# Out:
# conv_initialization： <class 'numpy.ndarray'>
# zero_padding： <class 'numpy.ndarray'>
# conv_single_step： <class 'numpy.float64'>
# conv_forward_1： <class 'numpy.float64'>
# conv_forward_2： <class 'numpy.ndarray'>
# conv_forward_3： <class 'numpy.ndarray'>
# conv_update_1： <class 'numpy.ndarray'>
# conv_update_2： <class 'numpy.ndarray'>
# maxpool_forward： <class 'numpy.ndarray'>
# flatten_forward： <class 'numpy.ndarray'>
# flatten_backward： <class 'numpy.ndarray'>
# model_1： <class 'numpy.ndarray'>
# model_2： <class 'numpy.ndarray'>
# model_3： <class 'numpy.ndarray'>
# model_4： <class 'numpy.ndarray'>
# basic_pred_test： <class 'numpy.ndarray'>
# basic_model_layers： <class 'list'>
# basic_model_parameters： <class 'list'>
# advanced_pred_test： <class 'numpy.ndarray'>

# %% [markdown]
# Expected output:<br>
# <small>
# conv_initialization： <class 'numpy.ndarray'> <br>
# zero_padding： <class 'numpy.ndarray'> <br>
# conv_single_step： <class 'numpy.float64'> <br>
# conv_forward_1： <class 'numpy.float64'> <br>
# conv_forward_2： <class 'numpy.ndarray'> <br>
# conv_forward_3： <class 'numpy.ndarray'> <br>
# conv_update_1： <class 'numpy.ndarray'> <br>
# conv_update_2： <class 'numpy.ndarray'> <br>
# maxpool_forward： <class 'numpy.ndarray'> <br>
# flatten_forward： <class 'numpy.ndarray'> <br>
# flatten_backward： <class 'numpy.ndarray'> <br>
# model_1： <class 'numpy.ndarray'> <br>
# model_2： <class 'numpy.ndarray'> <br>
# model_3： <class 'numpy.ndarray'> <br>
# model_4： <class 'numpy.ndarray'> <br>
# basic_pred_test： <class 'numpy.ndarray'> <br>
# basic_model_layers： <class 'list'> <br>
# basic_model_parameters： <class 'list'> <br>
# advanced_pred_test： <class 'numpy.ndarray'> <br>
# </small>
